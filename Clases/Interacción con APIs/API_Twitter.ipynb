# %% [markdown]
# # Interacción con Twitter mediante API y tweepy

# %% [markdown]
# La idea de esta notebook es dar algunos lineamientos sobre cómo utilizar la API de Twitter, mediante el paquete tweepy.
#
# Antes, es necesario hacer una aclaración: la API de Twitter involucra la utilización de claves para autenticar la sesión. Para esto, es necesario a partir de una cuenta de Twitter generar una cuenta desarrolladora. La cuenta puede generarse desde [esta](https://developer.twitter.com/en) página. La idea es responder ciertas preguntas para obtener el usuario, y una vez que nos lo den, debemos crear una aplicación y ahí generar las claves.
#
# Este proceso (sobre todo el de aceptación) puede demorar unos días. La posta es no poner palabras polémicas como bot o asociadas para que no nos lo nieguen. Poner que somos estudiantes suele ayudar.

# %%
from tweepy import OAuthHandler, StreamListener, Stream, API # Métodos para autenticación, escucha en vivo y guardado, y cuestiones generales
import time # Lo usamos para setear pausas en nuestro código
import re # Lo usamos para regular expresion

# %% [markdown]
# ## Utilización de Clases

# %% [markdown]
# En general, veremos en la web que muchos de los ejemplos de utilización de la API de Twitter en Python se basa en la creación de clases de objetos que implementen funciones y objetos propios de tweepy.
#
# En esta notebook, usamos dos sacados de [este](https://www.youtube.com/watch?v=wlnx-7cm4Gg) tutorial y uno (el primero) de elaboración propia (las diferencias saltan a la vista!).

# %%
class TwitterClosetTrends():
    """
    Clase para la descarga de tendencias
    Básicamente, tendremos dos métodos asociados a esta clase:
      - get_lugaresDisponiblesParaLatLong : a partir de pasarle una ubicación, nos da información sobre qué lugares hay tendencias disponibles
      - get_tendenciasCercanas : a partir de pasarle una ubicación (en formato woeid : ver documentación), nos devuelve las tendencias más recientes
    Para ambos métodos, es necesario autenticarse con las claves de Twitter Developer

    """

    def __init__(self):
        self.api = API()
        auth = OAuthHandler('1WPqzUedpK74Pn8nC95QLXFxx',
                            'nKxrkU0DcGnHUEcp9U6bYLOWsg0TIzPeiIK3hEtrWJeyPfErN5') # Pasamos las api keys
        
        auth.set_access_token('1009444901703086080-pYKl7ioNfEadMKxarNLEIX5swERbXf',
                              'UCWOHZ9Rw6NwFnQdlBCNRWeAWOy5b5boz2VohGDuSXxGt') # Pasamos las token keys
        self.api.auth = auth
        pass
    
    def get_lugaresDisponiblesParaLatLong(self, lat, long):
        """
        Le pasamos lat, long, nos devuelve los lugares disponibles más cercanos
        """
        
        lugaresDisponibles = self.api.trends_closest(lat, long) # Usamos uno de los métodos de la api pa
        
        return lugaresDisponibles
    
    def get_tendenciasCercanas(self, woeid):
        """
        Le pasamos el woeid de alguna ubicación y nos devuelve las tendencias cercanas
        """
        tendencias_cercanas = self.api.trends_place(woeid) # Pedimos las tendencias cercanas
        
        return tendencias_cercanas
    

class TwitterStreamer():
    """
    Class for streaming and processing live tweets.
    """
    def __init__(self):
        pass

    def stream_tweets(self, fetched_tweets_filename, hash_tag_list = '', languages = ['es'], follow = None):
        # This handles Twitter authetification and the connection to Twitter Streaming API
        listener = StdOutListener(fetched_tweets_filename)
        auth = OAuthHandler('1WPqzUedpK74Pn8nC95QLXFxx',
                            'nKxrkU0DcGnHUEcp9U6bYLOWsg0TIzPeiIK3hEtrWJeyPfErN5') # Pasamos las api keys
        
        auth.set_access_token('1009444901703086080-pYKl7ioNfEadMKxarNLEIX5swERbXf',
                              'UCWOHZ9Rw6NwFnQdlBCNRWeAWOy5b5boz2VohGDuSXxGt') # Pasamos las token keys
        
        stream = Stream(auth, listener, tweet_mode = 'extended')
        # This line filter Twitter Streams to capture data by the keywords: 
        if len(hash_tag_list) != 0:
            stream.filter(languages = languages,
                          track = hash_tag_list,
                          follow = follow,
                          )
        else:
            stream.sample(languages = languages,)
class StdOutListener(StreamListener):
    """
    Listener que guarda tweets en un archivo.
    """
    def __init__(self, fetched_tweets_filename):
        self.fetched_tweets_filename = fetched_tweets_filename

    def on_data(self, data):
        try:
            with open(self.fetched_tweets_filename, 'a') as tf:
                tf.write(data)
            return True
        except BaseException as e:
            print("Error on_data %s" % str(e))
        return True
    def on_error(self, status):
        print(status)

# %% [markdown]
# ## Implementación de la Búsqueda de Tendencias

# %% [markdown]
# Brevemente, podemos usar la búsqueda de tendencias para saber qué es lo que más está resonando en Twitter, cercano a una determinada locación.
#
# Esto puede permitir alimentar una búsqueda en vivo, a partir de las querys que nos otorga las propias tendencias

# %%
lugar
# Out:
# [{'country': 'Peru',
#   'countryCode': 'PE',
#   'name': 'Lima',
#   'parentid': 23424919,
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/418440',
#   'woeid': 418440}]

# %%
trends = TwitterClosetTrends() # Inicializamos el objeto de tendencias
lugar = trends.get_lugaresDisponiblesParaLatLong(lat = -20, long = -70) # Encontramos la (o las) ubicación más cercana al punto indicado con lat, long de la cual Twitter tiene datos
tendencias = trends.get_tendenciasCercanas(lugar[0]['woeid']) # Pedimos las tendencias asociadas a alguno de los lugares obtenidos previamente. Según la documentación, no tiene sentido hacer esto con una frecue

print('Las tendencias serán las cercanas a {}, {}'.format(lugar[0]['name'], lugar[0]['country']))
print('Las primeras 5 tendencias son:',)
print('\n'.join([tendencias[0]['trends'][i]['name'] for i in range(5)]))
# Out:
# Las tendencias serán las cercanas a Lima, Peru
# Las primeras 5 tendencias son:
# #ATEEZ_TheRealKing
# #ButterCelebrationParty
# Mujica
# Pinochet
# #9Hot100ProducerRM

# %%
tendencias[0]['trends']
# Out:
# [{'name': '#ATEEZ_TheRealKing',
#   'promoted_content': None,
#   'query': '%23ATEEZ_TheRealKing',
#   'tweet_volume': 392388,
#   'url': 'http://twitter.com/search?q=%23ATEEZ_TheRealKing'},
#  {'name': '#ButterCelebrationParty',
#   'promoted_content': None,
#   'query': '%23ButterCelebrationParty',
#   'tweet_volume': 260674,
#   'url': 'http://twitter.com/search?q=%23ButterCelebrationParty'},
#  {'name': 'Mujica',
#   'promoted_content': None,
#   'query': 'Mujica',
#   'tweet_volume': None,
#   'url': 'http://twitter.com/search?q=Mujica'},
#  {'name': 'Pinochet',
#   'promoted_content': None,
#   'query': 'Pinochet',
#   'tweet_volume': 11133,
#   'url': 'http://twitter.com/search?q=Pinochet'},
#  {'name': '#9Hot100ProducerRM',
#   'promoted_content': None,
#   'query': '%239Hot100ProducerRM',
#   'tweet_volume': 152004,
#   'url': 'http://twitter.com/search?q=%239Hot100ProducerRM'},
#  {'name': '#700kOnTheX',
#   'promoted_content': None,
#   'query': '%23700kOnTheX',
#   'tweet_volume': 10648,
#   'url': 'http://twitter.com/search?q=%23700kOnTheX'},
#  {'name': '#8YearsWithOurMoonJin',
#   'promoted_content': None,
#   'query': '%238YearsWithOurMoonJin',
#   'tweet_volume': 108076,
#   'url': 'http://twitter.com/search?q=%238YearsWithOurMoonJin'},
#  {'name': 'Corzo',
#   'promoted_content': None,
#   'query': 'Corzo',
#   'tweet_volume': None,
#   'url': 'http://twitter.com/search?q=Corzo'},
#  {'name': 'Colombia',
#   'promoted_content': None,
#   'query': 'Colombia',
#   'tweet_volume': 308165,
#   'url': 'http://twitter.com/search?q=Colombia'},
#  {'name': 'Allende',
#   'promoted_content': None,
#   'query': 'Allende',
#   'tweet_volume': None,
#   'url': 'http://twitter.com/search?q=Allende'},
#  {'name': 'Ramos',
#   'promoted_content': None,
#   'query': 'Ramos',
#   'tweet_volume': 30653,
#   'url': 'http://twitter.com/search?q=Ramos'},
#  {'name': 'LOUIS ACTOR',
#   'promoted_content': None,
#   'query': '%22LOUIS+ACTOR%22',
#   'tweet_volume': 11593,
#   'url': 'http://twitter.com/search?q=%22LOUIS+ACTOR%22'},
#  {'name': 'Black Swan',
#   'promoted_content': None,
#   'query': '%22Black+Swan%22',
#   'tweet_volume': 256704,
#   'url': 'http://twitter.com/search?q=%22Black+Swan%22'},
#  {'name': 'WE HOWL IN VICTORY',
#   'promoted_content': None,
#   'query': '%22WE+HOWL+IN+VICTORY%22',
#   'tweet_volume': 394642,
#   'url': 'http://twitter.com/search?q=%22WE+HOWL+IN+VICTORY%22'},
#  {'name': 'Arriba Perú',
#   'promoted_content': None,
#   'query': '%22Arriba+Per%C3%BA%22',
#   'tweet_volume': None,
#   'url': 'http://twitter.com/search?q=%22Arriba+Per%C3%BA%22'},
#  {'name': 'Advíncula',
#   'promoted_content': None,
#   'query': 'Adv%C3%ADncula',
#   'tweet_volume': None,
#   'url': 'http://twitter.com/search?q=Adv%C3%ADncula'},
#  {'name': 'ES HOY',
#   'promoted_content': None,
#   'query': '%22ES+HOY%22',
#   'tweet_volume': 250652,
#   'url': 'http://twitter.com/search?q=%22ES+HOY%22'},
#  {'name': 'Uruguay',
#   'promoted_content': None,
#   'query': 'Uruguay',
#   'tweet_volume': 32347,
#   'url': 'http://twitter.com/search?q=Uruguay'},
#  {'name': 'Pedro Francke',
#   'promoted_content': None,
#   'query': '%22Pedro+Francke%22',
#   'tweet_volume': None,
#   'url': 'http://twitter.com/search?q=%22Pedro+Francke%22'},
#  {'name': 'Peter Cárdenas',
#   'promoted_content': None,
#   'query': '%22Peter+C%C3%A1rdenas%22',
#   'tweet_volume': 16629,
#   'url': 'http://twitter.com/search?q=%22Peter+C%C3%A1rdenas%22'},
#  {'name': 'Gisela',
#   'promoted_content': None,
#   'query': 'Gisela',
#   'tweet_volume': 20574,
#   'url': 'http://twitter.com/search?q=Gisela'},
#  {'name': 'susel',
#   'promoted_content': None,
#   'query': 'susel',
#   'tweet_volume': None,
#   'url': 'http://twitter.com/search?q=susel'},
#  {'name': 'Gareca',
#   'promoted_content': None,
#   'query': 'Gareca',
#   'tweet_volume': None,
#   'url': 'http://twitter.com/search?q=Gareca'},
#  {'name': 'Guerrero',
#   'promoted_content': None,
#   'query': 'Guerrero',
#   'tweet_volume': 34198,
#   'url': 'http://twitter.com/search?q=Guerrero'},
#  {'name': 'Chile',
#   'promoted_content': None,
#   'query': 'Chile',
#   'tweet_volume': 172377,
#   'url': 'http://twitter.com/search?q=Chile'},
#  {'name': 'Tapia',
#   'promoted_content': None,
#   'query': 'Tapia',
#   'tweet_volume': None,
#   'url': 'http://twitter.com/search?q=Tapia'},
#  {'name': 'Gahela',
#   'promoted_content': None,
#   'query': 'Gahela',
#   'tweet_volume': None,
#   'url': 'http://twitter.com/search?q=Gahela'},
#  {'name': 'SKZ WOLFGANG ASSEMBLE',
#   'promoted_content': None,
#   'query': '%22SKZ+WOLFGANG+ASSEMBLE%22',
#   'tweet_volume': 537287,
#   'url': 'http://twitter.com/search?q=%22SKZ+WOLFGANG+ASSEMBLE%22'},
#  {'name': 'Carrillo',
#   'promoted_content': None,
#   'query': 'Carrillo',
#   'tweet_volume': None,
#   'url': 'http://twitter.com/search?q=Carrillo'},
#  {'name': 'Felix',
#   'promoted_content': None,
#   'query': 'Felix',
#   'tweet_volume': 142810,
#   'url': 'http://twitter.com/search?q=Felix'},
#  {'name': 'Lapadula',
#   'promoted_content': None,
#   'query': 'Lapadula',
#   'tweet_volume': None,
#   'url': 'http://twitter.com/search?q=Lapadula'},
#  {'name': 'Reyes',
#   'promoted_content': None,
#   'query': 'Reyes',
#   'tweet_volume': 37503,
#   'url': 'http://twitter.com/search?q=Reyes'},
#  {'name': 'REQUEST',
#   'promoted_content': None,
#   'query': 'REQUEST',
#   'tweet_volume': 804811,
#   'url': 'http://twitter.com/search?q=REQUEST'},
#  {'name': '#StrayKids_The_Final_King',
#   'promoted_content': None,
#   'query': '%23StrayKids_The_Final_King',
#   'tweet_volume': 551241,
#   'url': 'http://twitter.com/search?q=%23StrayKids_The_Final_King'},
#  {'name': '#CastilloMachistayHomofobico',
#   'promoted_content': None,
#   'query': '%23CastilloMachistayHomofobico',
#   'tweet_volume': None,
#   'url': 'http://twitter.com/search?q=%23CastilloMachistayHomofobico'},
#  {'name': '#STAYWeDidIt',
#   'promoted_content': None,
#   'query': '%23STAYWeDidIt',
#   'tweet_volume': 504880,
#   'url': 'http://twitter.com/search?q=%23STAYWeDidIt'},
#  {'name': '#스트레이키즈_승자의_함성',
#   'promoted_content': None,
#   'query': '%23%EC%8A%A4%ED%8A%B8%EB%A0%88%EC%9D%B4%ED%82%A4%EC%A6%88_%EC%8A%B9%EC%9E%90%EC%9D%98_%ED%95%A8%EC%84%B1',
#   'tweet_volume': 553681,
#   'url': 'http://twitter.com/search?q=%23%EC%8A%A4%ED%8A%B8%EB%A0%88%EC%9D%B4%ED%82%A4%EC%A6%88_%EC%8A%B9%EC%9E%90%EC%9D%98_%ED%95%A8%EC%84%B1'},
#  {'name': '#BAEKHYUN_TeaserQuest',
#   'promoted_content': None,
#   'query': '%23BAEKHYUN_TeaserQuest',
#   'tweet_volume': 490855,
#   'url': 'http://twitter.com/search?q=%23BAEKHYUN_TeaserQuest'},
#  {'name': '#XIUMIN_TeaserQuest',
#   'promoted_content': None,
#   'query': '%23XIUMIN_TeaserQuest',
#   'tweet_volume': 494961,
#   'url': 'http://twitter.com/search?q=%23XIUMIN_TeaserQuest'},
#  {'name': '#방탄소년단RM',
#   'promoted_content': None,
#   'query': '%23%EB%B0%A9%ED%83%84%EC%86%8C%EB%85%84%EB%8B%A8RM',
#   'tweet_volume': 42717,
#   'url': 'http://twitter.com/search?q=%23%EB%B0%A9%ED%83%84%EC%86%8C%EB%85%84%EB%8B%A8RM'},
#  {'name': '#EXOVerse_Loading',
#   'promoted_content': None,
#   'query': '%23EXOVerse_Loading',
#   'tweet_volume': 530941,
#   'url': 'http://twitter.com/search?q=%23EXOVerse_Loading'},
#  {'name': '#Namjoon',
#   'promoted_content': None,
#   'query': '%23Namjoon',
#   'tweet_volume': 39032,
#   'url': 'http://twitter.com/search?q=%23Namjoon'},
#  {'name': '#RolandGarros',
#   'promoted_content': None,
#   'query': '%23RolandGarros',
#   'tweet_volume': 41002,
#   'url': 'http://twitter.com/search?q=%23RolandGarros'},
#  {'name': '#KeikoLaPrisionTeEspera',
#   'promoted_content': None,
#   'query': '%23KeikoLaPrisionTeEspera',
#   'tweet_volume': None,
#   'url': 'http://twitter.com/search?q=%23KeikoLaPrisionTeEspera'},
#  {'name': '#이게바로_에이티즈의_멋인기라',
#   'promoted_content': None,
#   'query': '%23%EC%9D%B4%EA%B2%8C%EB%B0%94%EB%A1%9C_%EC%97%90%EC%9D%B4%ED%8B%B0%EC%A6%88%EC%9D%98_%EB%A9%8B%EC%9D%B8%EA%B8%B0%EB%9D%BC',
#   'tweet_volume': 410599,
#   'url': 'http://twitter.com/search?q=%23%EC%9D%B4%EA%B2%8C%EB%B0%94%EB%A1%9C_%EC%97%90%EC%9D%B4%ED%8B%B0%EC%A6%88%EC%9D%98_%EB%A9%8B%EC%9D%B8%EA%B8%B0%EB%9D%BC'},
#  {'name': '#FridayLivestream',
#   'promoted_content': None,
#   'query': '%23FridayLivestream',
#   'tweet_volume': 611063,
#   'url': 'http://twitter.com/search?q=%23FridayLivestream'},
#  {'name': '#2021BTSFESTA',
#   'promoted_content': None,
#   'query': '%232021BTSFESTA',
#   'tweet_volume': 627065,
#   'url': 'http://twitter.com/search?q=%232021BTSFESTA'},
#  {'name': '#BTS8thAnniversary',
#   'promoted_content': None,
#   'query': '%23BTS8thAnniversary',
#   'tweet_volume': 545944,
#   'url': 'http://twitter.com/search?q=%23BTS8thAnniversary'}]

# %% [markdown]
# ### Caso de Uso Particular: Búsqueda de Tendencias para disparar Alertas

# %% [markdown]
# Imaginemos que queremos armar un robot que "escuche" las tendencias de Twitter, asociadas a un determinado lugar, y nos dispare algún tipo de alerta (en este caso, sólo printeará, pero podría mandarnos un mail o lo que sea) cuando alguna tendencia matchee con alguna/s palabra/s que definamos previamente

# %%
def funcion_alerta_tendencias(lat, long, strings_alerta = ['vacunas'], cantidad_repeticiones = 1000, funcion = print):
    
    for i in range(cantidad_repeticiones): # Hacemos esto la cantidad de veces que definamos
        busqueda_tendencias = TwitterClosetTrends() # Inicializamos el objeto de busqueda de tendencias
        lugar = trends.get_lugaresDisponiblesParaLatLong(lat = lat, long = long) # Obtenemos los lugares
        tendencias = [trends.get_tendenciasCercanas(lugar[i]['woeid'])[0] for i in range(len(lugar))] # Obtenemos las tendencias. 

        for t in tendencias:
            t = t['trends']
            for trend in t:
                for string in strings_alerta:
                    if re.match('.*{}.*'.format(string.lower()), trend['name'].lower()) != None: # Criterio de matcheo de las strings de alerta y las tendencias encontradas
                        funcion(trend['name']) # Pedimos que ejecute la función que querramos en función de lo que estemos queriendo hacer
        if cantidad_repeticiones != 1:            
            time.sleep(60 * 5) # Le decimos que espere 5 minutos. Twitter actualiza la info cada 5 mins, así que no tendría sentido pedirle cada menos

# Esta es la función que pedimos que se active, pero podría ser otra tranquilamente
def print_alerta(t):
    print('Alerta! Hubo un match con: {}'.format(t))

# %%
funcion_alerta_tendencias(lat = -38, long = -58, strings_alerta = ['niunamenos','viernes'],cantidad_repeticiones = 1, funcion = print_alerta)
# Out:
# Alerta! Hubo un match con: #NiUnaMenos

# %% [markdown]
# ## Implementación de la Búsqueda en Vivo

# %% [markdown]
# Veamos cómo se implementa la búsqueda de tweets en vivo:

# %%
busqueda = TwitterStreamer() # Inicializamos el objeto
palabras = ['niunamenos'] # Definimos las palabras claves para filtrar
idioma = ['es'] # Definimos el idioma 
archivo = 'chocobar.txt' # Definimos el nombre del archivo en el cual se descargan los datos

# Inicializamos la búsqueda mediante el método stream_tweets

busqueda.stream_tweets(archivo, 
                       palabras,
                       idioma)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/lib/python3.7/http/client.py in _get_chunk_left(self)
#     557             try:
# --> 558                 chunk_left = self._read_next_chunk_size()
#     559             except ValueError:
#
# /usr/lib/python3.7/http/client.py in _read_next_chunk_size(self)
#     524         try:
# --> 525             return int(line, 16)
#     526         except ValueError:
#
# ValueError: invalid literal for int() with base 16: b''
#
# During handling of the above exception, another exception occurred:
#
# IncompleteRead                            Traceback (most recent call last)
# /usr/lib/python3.7/http/client.py in _readinto_chunked(self, b)
#     589             while True:
# --> 590                 chunk_left = self._get_chunk_left()
#     591                 if chunk_left is None:
#
# /usr/lib/python3.7/http/client.py in _get_chunk_left(self)
#     559             except ValueError:
# --> 560                 raise IncompleteRead(b'')
#     561             if chunk_left == 0:
#
# IncompleteRead: IncompleteRead(0 bytes read)
#
# During handling of the above exception, another exception occurred:
#
# IncompleteRead                            Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/urllib3/response.py in _error_catcher(self)
#     361             try:
# --> 362                 yield
#     363
#
# /usr/local/lib/python3.7/dist-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     443                 cache_content = False
# --> 444                 data = self._fp.read(amt)
#     445                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#
# /usr/lib/python3.7/http/client.py in read(self, amt)
#     460             b = bytearray(amt)
# --> 461             n = self.readinto(b)
#     462             return memoryview(b)[:n].tobytes()
#
# /usr/lib/python3.7/http/client.py in readinto(self, b)
#     494         if self.chunked:
# --> 495             return self._readinto_chunked(b)
#     496
#
# /usr/lib/python3.7/http/client.py in _readinto_chunked(self, b)
#     605         except IncompleteRead:
# --> 606             raise IncompleteRead(bytes(b[0:total_bytes]))
#     607
#
# IncompleteRead: IncompleteRead(0 bytes read)
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# <ipython-input-14-534eb3572808> in <module>()
#       8 busqueda.stream_tweets(archivo,
#       9                        palabras,
# ---> 10                        idioma)
#
# <ipython-input-2-84cda7a3f2b0> in stream_tweets(self, fetched_tweets_filename, hash_tag_list, languages, follow)
#      58             stream.filter(languages = languages,
#      59                           track = hash_tag_list,
# ---> 60                           follow = follow,
#      61                           )
#      62         else:
#
# /usr/local/lib/python3.7/dist-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# /usr/local/lib/python3.7/dist-packages/tweepy/streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# /usr/local/lib/python3.7/dist-packages/tweepy/streaming.py in _run(self)
#     318             # call a handler first so that the exception can be logged.
#     319             self.listener.on_exception(exc_info[1])
# --> 320             six.reraise(*exc_info)
#     321
#     322     def _data(self, data):
#
# /usr/local/lib/python3.7/dist-packages/six.py in reraise(tp, value, tb)
#     701             if value.__traceback__ is not tb:
#     702                 raise value.with_traceback(tb)
# --> 703             raise value
#     704         finally:
#     705             value = None
#
# /usr/local/lib/python3.7/dist-packages/tweepy/streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# /usr/local/lib/python3.7/dist-packages/tweepy/streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# /usr/local/lib/python3.7/dist-packages/tweepy/streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# /usr/local/lib/python3.7/dist-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     459                         # raised during streaming, so all calls with incorrect
#     460                         # Content-Length are caught.
# --> 461                         raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#     462
#     463         if data:
#
# /usr/lib/python3.7/contextlib.py in __exit__(self, type, value, traceback)
#     128                 value = type()
#     129             try:
# --> 130                 self.gen.throw(type, value, traceback)
#     131             except StopIteration as exc:
#     132                 # Suppress StopIteration *unless* it's the same exception that
#
# /usr/local/lib/python3.7/dist-packages/urllib3/response.py in _error_catcher(self)
#     378             except (HTTPException, SocketError) as e:
#     379                 # This includes IncompleteRead.
# --> 380                 raise ProtocolError('Connection broken: %r' % e, e)
#     381
#     382             # If no exception is thrown, we should avoid cleaning up
#
# ProtocolError: ('Connection broken: IncompleteRead(0 bytes read)', IncompleteRead(0 bytes read))
