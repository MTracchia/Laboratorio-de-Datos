# %% [markdown]
# <a href="https://colab.research.google.com/github/MTracchia/Laboratorio-de-Datos/blob/main/Clases/Web%20scraping/Contenido_est%C3%A1tico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Trabajando con el contenido estático de una página
#
# Vamos a comenzar trabajando en forma análoga a lo que hacíamos con las APIs, haciendo un simple request, nada más que ahora vamos a conseguir un código HTML en vez de datos bien formateadas en json o xml.
#
# Al hacer un request estamos sacando un foto de la página: su contenido es completamente estático. Por estático nos referimos a que no vamos a tener habilitadas opciones como *scrollear* o bien clickear algún que otro botón. Esto último es importante porque muchas veces hay contenido que solo se puede acceder a través de dichos métodos. Trabajar con contenido dinámico lo vamos a ver aparte de esta notebook (cuando trabajemos, por ejemplo, con la librería *selenium*).
#
# Dado que sacamos una foto de la página, recibimos un código que vamos a tener que *parsearlo*, es decir, convertirlo en un objeto manipulable en el que sea fácil navegar. Esto lo hacemos con el módulo *BeautifulSoup*.

# %%
# Importamos las librerías que vamos a utilizar
import requests
from bs4 import BeautifulSoup as BS

# %% [markdown]
# Comencemos como prueba con el *homepage* del diario La Nación. Recordar que una vez que hacemos el request ya dejamos de interactuar con la página:

# %%
# Hacemos un request a la página de La Nación
response = requests.get("https://www.lanacion.com.ar")

# Vemos el contenido que nos devolvió
print(response.content)
# Out:
# b'<!DOCTYPE html>\r\n<html lang="es">\r\n<head>\r\n\r\n\r\n<script>\r\n    \r\n    \r\n    var varnish = [\'\'];\r\n\r\n    Array.from = Array.from || (function () { var a = Object.prototype.toString, b = function (f) { return \'function\' == typeof f || \'[object Function]\' === a.call(f) }, c = function (f) { var g = +f; return isNaN(g) ? 0 : 0 != g && isFinite(g) ? (0 < g ? 1 : -1) * Math.floor(Math.abs(g)) : g }, d = Math.pow(2, 53) - 1, e = function (f) { var g = c(f); return Math.min(Math.max(g, 0), d) }; return function (g) { var h = this, i = Object(g); if (null == g) throw new TypeError(\'Array.from requires an array-like object - not null or undefined\'); var l, j = 1 < arguments.length ? arguments[1] : void 0; if (\'undefined\' != typeof j) { if (!b(j)) throw new TypeError(\'Array.from: when provided, the second argument must be a function\'); 2 < arguments.length && (l = arguments[2]) } for (var p, m = e(i.length), n = b(h) ? Object(new h(m)) : Array(m), o = 0; o < m;)p = i[o], n[o] = j ? \'undefined\' == typeof l ? j(p, o) : j.call(l, p, o) : p, o += 1; return n.length = m, n } }());\r\n\r\n    let metaRefresh = localStorage.getItem("CDmetaRefresh");\r\n    let countNotas = localStorage.getItem("countNotas");\r\n   \r\n\r\n    metaRefresh = metaRefresh != null ? "yes" : "no";\r\n    countNotas = countNotas ? countNotas : 0;\r\n\r\n    if (metaRefresh === "yes") {\r\n        localStorage.removeItem("CDmetaRefresh");\r\n    }\r\n\r\n    var dataLayer = [\r\n        {\r\n            "metarefresh": metaRefresh,\r\n            "pageType": "home",\r\n            "nota-pos": \'home\' === \'nota\' ? "," + countNotas : \'N/A\',\r\n            "valor": "N/A",\r\n            "TeaserPremium": ""\r\n        }\r\n    ];\r\n\r\n    \r\n    dataLayer[0].front = varnish[0] || "N/A";\r\n    dataLayer[0].host = varnish[1] || "N/A";\r\n    dataLayer[0].cache = "LNC-FRONT04";\r\n    dataLayer[0].build = "9.0.19899-HEAD-6de910e59";\r\n    \r\n\r\n   \r\n    if(\'home\' === "nota"){\r\n        dataLayer[0].notasLeidas = countNotas;\r\n        // dataLayer[0].countNotas = countNotas;\r\n    }\r\n</script>\r\n\r\n\r\n    <link href="/favicon.ico" rel="icon" type="image/x-icon">\r\n    <meta charset="UTF-8" name="viewport" content="width=device-width, initial-scale=1">\r\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n    \r\n<meta name="theme-color" content="#ffffff">\r\n<link rel="manifest" href="/manifest.json">\r\n    <link rel="dns-prefetch" href="//static.glanacion.com">\r\n<link rel="dns-prefetch" href="//cdn.livefyre.com">\r\n<link rel="dns-prefetch" href="//bucket.glanacion.com">\r\n<link rel="dns-prefetch" href="//bucket1.glanacion.com">\r\n<link rel="dns-prefetch" href="//bucket2.glanacion.com">\r\n<link rel="dns-prefetch" href="//bucket3.glanacion.com">\r\n<link rel="dns-prefetch" href="//ingresar.lanacion.com.ar">\r\n<link rel="dns-prefetch" href="//api-ingresar.lanacion.com.ar">\r\n<link rel="dns-prefetch" href="//api-paywall.lanacion.com.ar">\r\n<link rel="dns-prefetch" href="//wsresultados.lanacion.com.ar">\r\n<link rel="dns-prefetch" href="//api-contenidos.lanacion.com.ar">\r\n<link rel="dns-prefetch" href="//contenidos.lanacion.com.ar">\r\n    <meta name="msApplication-ID" content="width=device-width,initial-scale=1,minimum-scale=1">\r\n    <meta name="viewport" content="width=device-width,initial-scale=1,minimum-scale=1">\r\n    <meta name="copyright" content="LA NACION">\r\n    <meta name="title" content="\xc3\x9altimas noticias de Argentina y el mundo - LA NACION">\r\n    <meta name="description" content="LA NACION - Informaci\xc3\xb3n confiable en Internet. Noticias de Argentina y del mundo - \xc2\xa1Informate ya!">\r\n    <meta name="keywords" content="la naci\xc3\xb3n, diario, argentina, noticias, informaci\xc3\xb3n, pol\xc3\xadtica, econom\xc3\xada, finanzas, deportes, futbol, tenis, rugby, basquetbol, voleibol, formula 1, cultura, espect\xc3\xa1culos, cine, teatro, televisi\xc3\xb3n, humor, juegos, h ...

# %% [markdown]
# Listo! La información que nos dió el request es todo con lo que contamos. Ahora no queda otra que arremangarse y trabajar con esto. Para eso, *BeautifulSoup* nos da bastantes facilidades. Primero creamos la sopa:

# %%
# soup es un objeto manipulable creado a partir del contenido de la página y BeautifulSoup
soup = BS(response.content)

soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html lang="es">
# <head>
# <script>
#
#
#     var varnish = [''];
#
#     Array.from = Array.from || (function () { var a = Object.prototype.toString, b = function (f) { return 'function' == typeof f || '[object Function]' === a.call(f) }, c = function (f) { var g = +f; return isNaN(g) ? 0 : 0 != g && isFinite(g) ? (0 < g ? 1 : -1) * Math.floor(Math.abs(g)) : g }, d = Math.pow(2, 53) - 1, e = function (f) { var g = c(f); return Math.min(Math.max(g, 0), d) }; return function (g) { var h = this, i = Object(g); if (null == g) throw new TypeError('Array.from requires an array-like object - not null or undefined'); var l, j = 1 < arguments.length ? arguments[1] : void 0; if ('undefined' != typeof j) { if (!b(j)) throw new TypeError('Array.from: when provided, the second argument must be a function'); 2 < arguments.length && (l = arguments[2]) } for (var p, m = e(i.length), n = b(h) ? Object(new h(m)) : Array(m), o = 0; o < m;)p = i[o], n[o] = j ? 'undefined' == typeof l ? j(p, o) : j.call(l, p, o) : p, o += 1; return n.length = m, n } }());
#
#     let metaRefresh = localStorage.getItem("CDmetaRefresh");
#     let countNotas = localStorage.getItem("countNotas");
#
#
#     metaRefresh = metaRefresh != null ? "yes" : "no";
#     countNotas = countNotas ? countNotas : 0;
#
#     if (metaRefresh === "yes") {
#         localStorage.removeItem("CDmetaRefresh");
#     }
#
#     var dataLayer = [
#         {
#             "metarefresh": metaRefresh,
#             "pageType": "home",
#             "nota-pos": 'home' === 'nota' ? "," + countNotas : 'N/A',
#             "valor": "N/A",
#             "TeaserPremium": ""
#         }
#     ];
#
#
#     dataLayer[0].front = varnish[0] || "N/A";
#     dataLayer[0].host = varnish[1] || "N/A";
#     dataLayer[0].cache = "LNC-FRONT04";
#     dataLayer[0].build = "9.0.19899-HEAD-6de910e59";
#
#
#
#     if('home' === "nota"){
#         dataLayer[0].notasLeidas = countNotas;
#         // dataLayer[0].countNotas = countNotas;
#     }
# </script>
# <link href="/favicon.ico" rel="icon" type="image/x-icon"/>
# <meta charset="utf-8" content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="#ffffff" name="theme-color"/>
# <link href="/manifest.json" rel="manifest"/>
# <link href="//static.glanacion.com" rel="dns-prefetch"/>
# <link href="//cdn.livefyre.com" rel="dns-prefetch"/>
# <link href="//bucket.glanacion.com" rel="dns-prefetch"/>
# <link href="//bucket1.glanacion.com" rel="dns-prefetch"/>
# <link href="//bucket2.glanacion.com" rel="dns-prefetch"/>
# <link href="//bucket3.glanacion.com" rel="dns-prefetch"/>
# <link href="//ingresar.lanacion.com.ar" rel="dns-prefetch"/>
# <link href="//api-ingresar.lanacion.com.ar" rel="dns-prefetch"/>
# <link href="//api-paywall.lanacion.com.ar" rel="dns-prefetch"/>
# <link href="//wsresultados.lanacion.com.ar" rel="dns-prefetch"/>
# <link href="//api-contenidos.lanacion.com.ar" rel="dns-prefetch"/>
# <link href="//contenidos.lanacion.com.ar" rel="dns-prefetch"/>
# <meta content="width=device-width,initial-scale=1,minimum-scale=1" name="msApplication-ID"/>
# <meta content="width=device-width,initial-scale=1,minimum-scale=1" name="viewport"/>
# <meta content="LA NACION" name="copyright"/>
# <meta content="Últimas noticias de Argentina y el mundo - LA NACION" name="title"/>
# <meta content="LA NACION - Información confiable en Internet. Noticias de Argentina y del mundo - ¡Informate ya!" name="description"/>
# <meta content="la nación, diario, argentina, noticias, información, política, economía, finanzas, deportes, futbol, tenis, rugby, basquetbol, voleibol, formula 1, cultura, espectáculos, cine, teatro, televisión, humor, juegos, horóscopo, clima, pronostico, mapa, vinos, restaurantes, quiniela, loteria, nik, criptograma literario, liniers, internacional, el mundo, ciencia, últimas noticias, clasificados" name="keywords"/>
# <meta content="website" property="og:type"/>
# <meta content="Últimas noticias de Argentina y el mundo - LA NACION" property="og:title"/>
# <meta content="Información confiable en Internet. Noticias de Argentina y del mundo - ¡Informate ya!" property="og:description"/>
# <meta content="http://www.lanacion.com.ar" property="og:url"/>
# <meta content="LA NACION" name="application-name"/>
# <meta content="http://www.lanacion.com.ar" name="msapplication-starturl"/>
# <meta content="Noticias actualizadas las 24 hs." name="msapplication-tooltip"/>
# <meta content="width=800;height=600" name="msapplication-window"/>
# <meta content="frontpage" name="cXenseParse:pageclass"/>
# <meta content="name=Ultimas noticias;action-uri=http://www.lanacion.com.ar/ultimas-noticias;icon-uri=http://www.lanacion.com.ar/item1.ico" name="msapplication-task"/>
# <meta content="name=Tránsito;action-uri=https://www.lanacion.com.ar/transito;icon-uri=http://www.lanacion.com.ar/item2.ico" name="msapplication-task"/>
# <meta content="name=Pronóstico;action-uri=http://servicios.lanacion.com.ar/informacion-general/pronostico;icon-uri=http://www.lanacion.com.ar/item3.ico" name="msapplication-task"/>
# <meta content="name=Horóscopo;action-uri=https://www.lanacion.com.ar/horoscopo;icon-uri=http://www.lanacion.com.ar/item4.ico" name="msapplication-task"/>
# <link href="/manifest.json" rel="manifest"/>
# <script>window.config={"Statics":{"BucketUrl":"//bucket{nro}.glanacion.com","DominioUrl":"//www.lanacion.com.ar/","GaleriaUrl":"//api-contenidos.lanacion.com.ar/json/V2/galeria/","FacebookId":205326199490321.0,"LoginUrl":"https://ingresar.lanacion.com.ar/ingresar/D/1/?callback=","SitioSeguroRegistracion":"https://ingresar.lanacion.com.ar","LogoutUrl":"/logout.html","APILoginUrl":"https://api-ingresar.lanacion.com.ar","DominioCookie":".lanacion.com.ar","ApiRankingSitioUrl":"acumulado/ranking-sitio-","ApiContenidoUrlRoot":"//api-contenidos.lanacion.com.ar/json/v2/","BucketClubLnUrl":"//bucket.glanacion.com/Club.LN/anexos/fotos","ApiPromoClubLnUrl":"clubLn/establecimientos/activos","ApiUltimasNoticias":"sitio/1?ultimas_noticias=1","TableroUrl":"//wsresultados.lanacion.com.ar/service1.svc/","SiteIdLF":356483,"ApiLiveFireUrl":"https://{livefyre-domainName}.bootstrap.fyre.co/api/v3.0/hottest/?site={SiteId_Livefyre}&number={cantidad de notas}","BuscadorUrl":"//buscar.lanacion.com.ar/","CookieExpiration":8640000000.0,"ReloginValidation":8121600000.0,"ApiPaywall":"https://api-paywall.lanacion.com.ar","ApiSuscripcion":"/1/SuscripcionV1/ObtenerSuscripcionDigitalAnalytics","BasePath":"//static.glanacion.com/v2/ln","ContenidosUrlRoot":"//contenidos.lanacion.com.ar","ReloginUrl":"/relogin.html","ApiNavAnonimaHome":"//api-contenidos.lanacion.com.ar/json/v2/acumulado/refererHome","ApiNavAnonimaExt":"//api-contenidos.lanacion.com.ar/json/v2/acumulado/refererExterno","CookieExpirationNotifications":2419200000.0,"ApiNotificaciones":"https://notificaciones.lanacion.com.ar/api/","topicName":"pwatemp","ApiContenidoUrlRaiz":"//api-contenidos.lanacion.com.ar/json/"},"Sitio":{"Id":1},"Firebase":{"apiKey":"AIzaSyCFxG5eKZiyU1DDlg7yZw4JzblfO6pc0m4","authDomain":"lanacion-92a91.firebaseapp.com","databaseURL":"https://lanacion-92a91.firebaseio.com","messagingSenderId":221085116662.0,"projectId":"lanacion-92a91","storageBucket":"lanacion-92a91.appspot.com"}}</script>
# <script src="https://www.googletagservices.com/tag/js/gpt.js"></script>
# <script>
#     function testQueryString() {
#         var urlParams = new URLSearchParams(window.location.search);
#         if (urlParams.get('adstest') == "true" || urlParams.get('adtest') == "true") {
#             return "true";
#         }
#         return "false";
#     }
#
#     function navegg() {
#         (function (w) {
#             try {
#                 var name, col, persona = JSON.parse(window.localStorage.getItem("nvgpersona18894"));
#                 for (col in persona) {
#                     name = "nvg_" + col;
#                     name = name.substring(0, 10);
#                     if (typeof (googletag) == "object")
#                         googletag.pubads().setTargeting(name, persona[col]);
#                     if (typeof (GA_googleAddAttr) == "function")
#                         GA_googleAddAttr(name, persona[col]);
#                 }
#             } catch (e) {
#                 console.error(e);
#             }
#         })(window);
#     }
#
#     function prebidConfig() {
#     }
#
#     function leerCookie(nombrecookie) {
#         var laCookie = '' + document.cookie;
#         var indice = laCookie.indexOf(nombrecookie);
#
#         if (indice == -1 || nombrecookie == '') {
#             return '';
#         }
#
#         var indiceUno = laCookie.indexOf(';', indice);
#         var indiceDos = laCookie.indexOf('&', indice);
#
#         if (((indiceUno > indiceDos) && (indiceDos != -1)) || ((indiceUno == -1) && (indiceDos != -1))) {
#             indiceUno = indiceDos;
#         }
#
#         if (indiceUno == -1) {
#             indiceUno = laCookie.length;
#         }
#         return unescape(laCookie.substring(indice + nombrecookie.length + 1, indiceUno));
#     }
#
#     function getBannersConfig() {
#
#         let userSuscriptorType = leerCookie("ProductoPremiumId").split(",");
#         userSuscriptorType.forEach(function(element, index) {
#             if (element == "")
#                 userSuscriptorType.splice(index, 1);
#         });
#
#         for (let suscriptorId of userSuscriptorType) {
#
#             switch (window.DFP.ads.deviceResolution) {
#                 case "_dsk":
#                     hideBannerByUserAndSection(suscriptorId.trim(), "home", "Desktop");
#                     break;
#                 case "_tab":
#                     hideBannerByUserAndSection(suscriptorId.trim(), "home", "Tablet");
#                     break;
#                 case "_mob":
#                     hideBannerByUserAndSection(suscriptorId.trim(), "home", "Mobile");
#                     break;
#             }
#         }
#     }
#
#     function capitalizeFirstLetter(string) {
#         return string.charAt(0).toUpperCase() + string.slice(1);
#     }
#
#     function hideBannerByUserAndSection(userId, section, dispositivo) {
#         let configBanner = {"Desktop":{"Nota":[{"UserType":"2","Banners":["caja1_dsk","middle1_dsk","middle_teads_dsk","adhesion_dsk","1x1_dsk"]},{"UserType":"4","Banners":["caja1_dsk","middle1_dsk","middle_teads_dsk","adhesion_dsk","1x1_dsk"]},{"UserType":"6","Banners":["caja1_dsk","middle1_dsk","middle_teads_dsk","adhesion_dsk","1x1_dsk"]}],"Home":[{"UserType":"2","Banners":["adhesion_dsk","1x1_dsk"]},{"UserType":"4","Banners":["adhesion_dsk","1x1_dsk"]},{"UserType":"6","Banners":["adhesion_dsk","1x1_dsk"]}],"Acumulado":[{"UserType":"2","Banners":["adhesion_dsk","1x1_dsk"]},{"UserType":"4","Banners":["adhesion_dsk","1x1_dsk"]},{"UserType":"6","Banners":["adhesion_dsk","1x1_dsk"]}],"Content_lab":[{"UserType":"2","Banners":[]},{"UserType":"4","Banners":[]},{"UserType":"6","Banners":[]}]},"Tablet":{"Nota":[{"UserType":"2","Banners":["middle_teads_tab","inread_tab","1x1_tab"]},{"UserType":"4","Banners":["middle_teads_tab","inread_tab","1x1_tab"]},{"UserType":"6","Banners":["middle_teads_tab","inread_tab","1x1_tab"]}],"Home":[{"UserType":"2","Banners":["adhesion_tab","1x1_tab"]},{"UserType":"4","Banners":["adhesion_tab","1x1_tab"]},{"UserType":"6","Banners":["adhesion_tab","1x1_tab"]}],"Acumulado":[{"UserType":"2","Banners":["1x1_tab"]},{"UserType":"4","Banners":["1x1_tab"]},{"UserType":"6","Banners":["1x1_tab"]}],"Content_lab":[{"UserType":"2","Banners":[]},{"UserType":"4","Banners":[]},{"UserType":"6","Banners":[]}]},"Mobile":{"Nota":[{"UserType":"2","Banners":["middle_teads_mob","caja2_mob","1x1_mob"]},{"UserType":"4","Banners":["middle_teads_mob","caja2_mob","1x1_mob"]},{"UserType":"6","Banners":["middle_teads_mob","caja2_mob","1x1_mob"]}],"Home":[{"UserType":"2","Banners":["adhesion_mob","1x1_mob"]},{"UserType":"4","Banners":["adhesion_mob","1x1_mob"]},{"UserType":"6","Banners":["adhesion_mob","1x1_mob"]}],"Acumulado":[{"UserType":"2","Banners":["1x1_mob"]},{"UserType":"4","Banners":["1x1_mob"]},{"UserType":"6","Banners":["1x1_mob"]}],"Content_lab":[{"UserType":"2","Banners":[]},{"UserType":"4","Banners":[]},{"UserType":"6","Banners":[]}]}};
#         configBanner = configBanner[dispositivo][capitalizeFirstLetter(section)];
#
#         configBanner.forEach(function(data) {
#             if (data.UserType == userId) {
#             window.DFP.ads.bannersOcultar += data.Banners;
#             }
#         });
#     }
#
#     function showBannerResolution(bannerId) {
#         if (bannerId.indexOf(window.DFP.ads.deviceResolution) !== -1 && (window.DFP.ads.bannersOcultar == "" || window.DFP.ads.bannersOcultar.indexOf(bannerId) === -1)) {
#             return true;
#         }
#       return false;
#     }
#
#     function tabIsActive() {
#         var hidden, visibilityChange;
#         if (typeof document.hidden !== "undefined") { // Opera 12.10 and Firefox 18 and later support
#             hidden = "hidden";
#             visibilityChange = "visibilitychange";
#         } else if (typeof document.msHidden !== "undefined") {
#             hidden = "msHidden";
#             visibilityChange = "msvisibilitychange";
#         } else if (typeof document.webkitHidden !== "undefined") {
#             hidden = "webkitHidden";
#             visibilityChange = "webkitvisibilitychange";
#         }
#
#         if (document[hidden]) {
#             window.DFP.ads.tabIsActive = "false";
#         } else {
#             window.DFP.ads.tabIsActive = "true";
#         }
#     }
#
#     function tabRegisterEvent() {
#         var hidden, visibilityChange;
#         if (typeof document.hidden !== "undefined") { // Opera 12.10 and Firefox 18 and later support
#             hidden = "hidden";
#             visibilityChange = "visibilitychange";
#         } else if (typeof document.msHidden !== "undefined") {
#             hidden = "msHidden";
#             visibilityChange = "msvisibilitychange";
#         } else if (typeof document.webkitHidden !== "undefined") {
#             hidden = "webkitHidden";
#             visibilityChange = "webkitvisibilitychange";
#         }
#
#         if (typeof document.addEventListener === "undefined" || hidden === undefined) {
#             console.log("This demo requires a browser, such as Google Chrome or Firefox, that supports the Page Visibility API.");
#         } else {
#         // Handle page visibility change
#             document.addEventListener(visibilityChange, function() {
#                 if (document[hidden]) {
#                     window.DFP.ads.tabIsActive = "false";
#                 } else {
#                     window.DFP.ads.tabIsActive = "true";
#                 }
#             }, false);
#         }
#     }
#
# </script>
# <script>
#
#     var clickeoBotonHome = false;
#     const scrollToPoint = (to, duration) => {
#
#             var start = document.body.scrollTop || document.documentElement.scrollTop,
#                 change = to - start,
#                 currentTime = 0,
#                 increment = 20;
#
#             var animateScroll = function () {
#                 currentTime += increment;
#                 const val = Math.easeInOutQuad(currentTime, start, change, duration);
#
#                 scroll(0, val)
#                 if (currentTime < duration) {
#                     setTimeout(animateScroll, increment);
#                 }
#             };
#             animateScroll();
#
#
#     }
#
#     Math.easeInOutQuad = function (t, b, c, d) {
#         t /= d / 2;
#         if (t < 1) return c / 2 * t * t + b;
#         t--;
#         return -c / 2 * (t * (t - 2) - 1) + b;
#     };
#
#     const initMegaTopDesktop = () => {
#         const anchoPantalla = window.innerWidth;
#         if (showBannerResolution('megatop_dsk') && anchoPantalla >= 1024) {
#             const altoPantalla = window.innerHeight || document.documentElement.clientHeight
#             let clickeoBoton = false;
#             const megatopContainerDsk = document.getElementById('container-megatop_dsk')
#             megatopContainerDsk.style.height = 0;
#             megatopContainerDsk.style.display = 'block';
#             megatopContainerDsk.style.transition = 'height 1000ms ease-in-out';
#             setTimeout(() => {
#                 megatopContainerDsk.style.height = altoPantalla + 'px';
#             }, 0)
#
#
#
#             document.getElementById('btn-bajar-megatop_dsk').addEventListener('click', function () {
#                 scrollToPoint(megatopContainerDsk.clientHeight + 1, 800)
#                 clickeoBoton = true;
#             })
#
#             setTimeout(() => {
#                // clickeoBoton = clickeoBotonHome;
#                 const positionMain = megatopContainerDsk.clientHeight + 1
#                 if (!clickeoBoton && window.scrollY < positionMain) {
#                     scrollToPoint(positionMain, 800)
#                 }
#             }, 10000)
#         }
#     }
#
#     const initMegaTopMobile = () => {
#         const anchoPantalla = window.innerWidth;
#         if (showBannerResolution('megatop_mob') && anchoPantalla <= 639) {
#             const altoPantalla = window.innerHeight || document.documentElement.clientHeight
#             const megatopContainerMob = document.getElementById('container-megatop_mob')
#             megatopContainerMob.style.height = 0;
#             megatopContainerMob.style.display = 'block';
#             megatopContainerMob.style.transition = 'height 1000ms ease-in-out';
#             setTimeout(() => {
#                 megatopContainerMob.style.height = altoPantalla + 'px';
#             }, 0)
#
#             let clickeoBoton = false;
#              clickeoBoton = false;
#             document.getElementById('btn-bajar-megatop_mob').addEventListener('click', function () {
#                 scrollToPoint(megatopContainerMob.clientHeight + 1, 800)
#                 clickeoBoton = true;
#             })
#
#             setTimeout(() => {
#                 const positionMain = megatopContainerMob.clientHeight + 1
#                 if (!clickeoBoton && window.scrollY < positionMain) {
#                     scrollToPoint(positionMain, 800)
#                 }
#             }, 10000)
#         }
#     }
# </script>
# <script>
#     const initComercial = (banner) => {
#         const anchoPantalla = window.innerWidth;
#         let showBanner = false;
#         if ((showBannerResolution(banner)) && ((banner == 'comercial_dsk' && anchoPantalla >= 1024) || (banner == 'comercial_mob' && anchoPantalla <= 639))) {
#             showBanner = true;
#         }
#
#         if (showBanner) {
#             let clickeoBoton = false;
#             const comercialContainer = document.getElementById(`container-${banner}`)
#             comercialContainer.style.display = 'flex';
#             comercialContainer.style.transition = 'height 1000ms ease-in-out';
#
#             document.getElementById(`btn-bajar-${banner}`).addEventListener('click', function () {
#                 comercialContainer.style.display = 'none';
#                 clickeoBoton = true;
#             });
#
#             setTimeout(() => {
#                 if (!clickeoBoton)
#                     comercialContainer.style.display = 'none';
#             }, 10000)
#         }
#     }
# </script>
# <script language="JavaScript" type="text/javascript">
#     function cerrarAdhesion(adhesion) {
#         function f_styles(element, styles) {
#             "use strict";
#             Object.keys(styles).forEach(function (x) {
#                 element.style[x] = styles[x];
#             });
#         }
#         var defaultButton = "https://i.e-planning.net/esb/4/1/3fb8/ea7d639f35554c9b/close.png";
#         imgBtnCerrar = document.createElement("img");
#         f_styles(imgBtnCerrar, { "width": "20px", "height": "20", "z-index": "9999", "top": "0px", "position": "absolute", "right": "0px", "left": "auto", "cursor": "pointer" });
#         imgBtnCerrar.src = defaultButton;
#
#         imgBtnCerrar.onclick = function () {
#             document.querySelector('#' + adhesion).style.display = "none";
#         };
#         document.querySelector('#' + adhesion).append(imgBtnCerrar);
#     }
#
#
#
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#
#     window.DFP = {};
#     window.DFP.ads = {};
#     window.DFP.ads.bannersOcultar = "";
#     window.DFP.ads.sitioId = "";
#     tabRegisterEvent();
#     tabIsActive();
#
#     var bannersHome = {};
#
#     var imgscaja1 = null;
#     var imgscaja2 = null;
#     var imgscaja3 = null;
#     var imgscaja4 = null;
#     var flagrefresh = 0;
#
#     let isMobile = false;
#     (function (a) { if (/(android|bb\d+|meego).+mobile|avantgo|bada\/|blackberry|blazer|compal|elaine|fennec|hiptop|iemobile|ip(hone|od)|iris|kindle|lge |maemo|midp|mmp|mobile.+firefox|netfront|opera m(ob|in)i|palm( os)?|phone|p(ixi|re)\/|plucker|pocket|psp|series(4|6)0|symbian|treo|up\.(browser|link)|vodafone|wap|windows ce|xda|xiino/i.test(a) || /1207|6310|6590|3gso|4thp|50[1-6]i|770s|802s|a wa|abac|ac(er|oo|s\-)|ai(ko|rn)|al(av|ca|co)|amoi|an(ex|ny|yw)|aptu|ar(ch|go)|as(te|us)|attw|au(di|\-m|r |s )|avan|be(ck|ll|nq)|bi(lb|rd)|bl(ac|az)|br(e|v)w|bumb|bw\-(n|u)|c55\/|capi|ccwa|cdm\-|cell|chtm|cldc|cmd\-|co(mp|nd)|craw|da(it|ll|ng)|dbte|dc\-s|devi|dica|dmob|do(c|p)o|ds(12|\-d)|el(49|ai)|em(l2|ul)|er(ic|k0)|esl8|ez([4-7]0|os|wa|ze)|fetc|fly(\-|_)|g1 u|g560|gene|gf\-5|g\-mo|go(\.w|od)|gr(ad|un)|haie|hcit|hd\-(m|p|t)|hei\-|hi(pt|ta)|hp( i|ip)|hs\-c|ht(c(\-| |_|a|g|p|s|t)|tp)|hu(aw|tc)|i\-(20|go|ma)|i230|iac( |\-|\/)|ibro|idea|ig01|ikom|im1k|inno|ipaq|iris|ja(t|v)a|jbro|jemu|jigs|kddi|keji|kgt( |\/)|klon|kpt |kwc\-|kyo(c|k)|le(no|xi)|lg( g|\/(k|l|u)|50|54|\-[a-w])|libw|lynx|m1\-w|m3ga|m50\/|ma(te|ui|xo)|mc(01|21|ca)|m\-cr|me(rc|ri)|mi(o8|oa|ts)|mmef|mo(01|02|bi|de|do|t(\-| |o|v)|zz)|mt(50|p1|v )|mwbp|mywa|n10[0-2]|n20[2-3]|n30(0|2)|n50(0|2|5)|n7(0(0|1)|10)|ne((c|m)\-|on|tf|wf|wg|wt)|nok(6|i)|nzph|o2im|op(ti|wv)|oran|owg1|p800|pan(a|d|t)|pdxg|pg(13|\-([1-8]|c))|phil|pire|pl(ay|uc)|pn\-2|po(ck|rt|se)|prox|psio|pt\-g|qa\-a|qc(07|12|21|32|60|\-[2-7]|i\-)|qtek|r380|r600|raks|rim9|ro(ve|zo)|s55\/|sa(ge|ma|mm|ms|ny|va)|sc(01|h\-|oo|p\-)|sdk\/|se(c(\-|0|1)|47|mc|nd|ri)|sgh\-|shar|sie(\-|m)|sk\-0|sl(45|id)|sm(al|ar|b3|it|t5)|so(ft|ny)|sp(01|h\-|v\-|v )|sy(01|mb)|t2(18|50)|t6(00|10|18)|ta(gt|lk)|tcl\-|tdg\-|tel(i|m)|tim\-|t\-mo|to(pl|sh)|ts(70|m\-|m3|m5)|tx\-9|up(\.b|g1|si)|utst|v400|v750|veri|vi(rg|te)|vk(40|5[0-3]|\-v)|vm40|voda|vulc|vx(52|53|60|61|70|80|81|83|85|98)|w3c(\-| )|webc|whit|wi(g |nc|nw)|wmlb|wonu|x700|yas\-|your|zeto|zte\-/i.test(a.substr(0, 4)) || /Tablet|iPad/i.test(a)) isMobile = true; })(navigator.userAgent || navigator.vendor || window.opera);
#     let tablet = false;
#     if (screen.width >= 1023) { tablet = true; }
#     if (screen.height >= 1023) { tablet = true; }
#     let metaRefreshKv = localStorage.getItem("CDmetaRefresh");
#     metaRefreshKv = metaRefreshKv != null ? "true" : "false";
#     if (isMobile) {
#         if (tablet) {
#             window.DFP.ads.deviceResolution = "_tab";
#             googletag.cmd.push(function () {
#                 bannersHome.cabezal_tab = googletag.defineSlot('/133919216/la_nacion_tablet/Home/cabezal_tab', [728, 90], 'cabezal_tab').addService(googletag.pubads());
#                 bannersHome["1x1_tab"] = googletag.defineSlot('/133919216/la_nacion_tablet/Home/1x1_tab', [1, 1], '1x1_tab').addService(googletag.pubads());
#                 bannersHome.adhesion_tab = googletag.defineSlot('/133919216/la_nacion_tablet/Home/adhesion_tab', [728, 90], 'adhesion_tab').addService(googletag.pubads());
#             });
#
#             googletag.pubads().addEventListener('slotRenderEnded', function (event) {
#                 if (event.slot === bannersHome.adhesion_tab) {
#                     cerrarAdhesion(`adhesion_tab`);
#                 }
#             });
#         } else {
#             window.DFP.ads.deviceResolution = "_mob";
#             googletag.cmd.push(function () {
#                 bannersHome.megatop_mob = googletag.defineSlot('/133919216/la_nacion_mobile/Home/megatop_mob', [[320, 480], 'fluid'], 'megatop_mob').addService(googletag.pubads());
#                 bannersHome.comercial_mob = googletag.defineSlot('/133919216/la_nacion_mobile/Home/comercial_mob', [[1, 1], [320, 480]], 'comercial_mob').addService(googletag.pubads());
#                 bannersHome["1x1_mob"] = googletag.defineSlot('/133919216/la_nacion_mobile/Home/1x1_mob', [1, 1], '1x1_mob').addService(googletag.pubads());
#                 bannersHome.sticky1_mob = googletag.defineSlot('/133919216/la_nacion_mobile/Home/sticky1_mob', [[320, 50], [320, 100], [300, 100], [1, 1]], 'sticky1_mob').addService(googletag.pubads());
#                 bannersHome.sticky2_mob = googletag.defineSlot('/133919216/la_nacion_mobile/Home/sticky2_mob', [[320, 50], [300, 100], [1, 1]], 'sticky2_mob').addService(googletag.pubads());
#                 bannersHome.caja1_mob = googletag.defineSlot('/133919216/la_nacion_mobile/Home/caja1_mob', [[300, 450], [320, 50], [300, 250], [320, 100]], 'caja1_mob').addService(googletag.pubads());
#                 bannersHome.adhesion_mob = googletag.defineSlot('/133919216/la_nacion_mobile/Home/adhesion_mob', [320, 50], 'adhesion_mob').addService(googletag.pubads());
#             });
#             googletag.pubads().addEventListener('slotRenderEnded', function (event) {
#
#                 if (event.slot === bannersHome.adhesion_mob) {
#                     cerrarAdhesion(`adhesion_mob`);
#                 }
#                 if (event.slot === bannersHome.megatop_mob && event.slot.getHtml()) {
#                     initMegaTopMobile();
#                 }
#                 if (event.slot == bannersHome.comercial_mob && event.slot.getHtml()) {
#                     initComercial('comercial_mob');
#                 }
#             });
#         }
#     } else {
#         window.DFP.ads.deviceResolution = "_dsk";
#         googletag.cmd.push(function () {
#             bannersHome.megatop_dsk = googletag.defineSlot('/133919216/la_nacion_desktop/Home/megatop_dsk', [[800, 600], 'fluid'], 'megatop_dsk').addService(googletag.pubads());
#             bannersHome.comercial_dsk = googletag.defineSlot('/133919216/la_nacion_desktop/Home/comercial_dsk', [[1, 1], [800, 600]], 'comercial_dsk').addService(googletag.pubads());
#             bannersHome["1x1_dsk"] = googletag.defineSlot('/133919216/la_nacion_desktop/Home/1x1_dsk', [1, 1], '1x1_dsk').addService(googletag.pubads());
#             bannersHome.cabezal_dsk = googletag.defineSlot('/133919216/la_nacion_desktop/Home/cabezal_dsk', [[728, 90], [920, 100]], 'cabezal_dsk').addService(googletag.pubads());
#             bannersHome.megalateral_dsk = googletag.defineSlot('/133919216/la_nacion_desktop/Home/megalateral_dsk', [120, 600], 'megalateral_dsk').addService(googletag.pubads());
#             bannersHome.adhesion_dsk = googletag.defineSlot('/133919216/la_nacion_desktop/Home/adhesion_dsk', [728, 90], 'adhesion_dsk').addService(googletag.pubads());
#
#
#             googletag.pubads().addEventListener('slotRenderEnded', function (event) {
#                 if (event.slot === bannersHome.adhesion_dsk) {
#                     cerrarAdhesion('adhesion_dsk');
#                 }
#                 if (event.slot === bannersHome.megatop_dsk && event.slot.getHtml()) {
#                     initMegaTopDesktop();
#                 }
#                 if (event.slot == bannersHome.comercial_dsk && event.slot.getHtml()) {
#                     initComercial('comercial_dsk');
#                 }
#             });
#
#             const mapping_cabezal_dsk = googletag.sizeMapping().
#                 addSize([1920, 0], [[728, 90], [920, 100], [920, 170]]).
#                 addSize([1366, 0], [[728, 90], [920, 100], [920, 170]]).
#                 addSize([1200, 0], [[728, 90], [920, 100], [920, 170]]).
#                 build();
#             bannersHome.cabezal_dsk.defineSizeMapping(mapping_cabezal_dsk);
#
#
#             const megalateral_dsk_mapping = googletag.sizeMapping().
#                 addSize([1920, 0], [[120, 600], [300, 600], [250, 600], [160, 600]]).
#                 addSize([1366, 0], [[120, 600], [300, 600], [250, 600], [160, 600]]).
#                 addSize([1200, 0], [[120, 600], [300, 600], [250, 600], [160, 600]]).
#                 build();
#             bannersHome.megalateral_dsk.defineSizeMapping(megalateral_dsk_mapping);
#
#             const adhesion_dsk_mapping = googletag.sizeMapping().
#                 addSize([1920, 0], [[728, 90], [920, 100]]).
#                 addSize([1366, 0], [[728, 90], [920, 100]]).
#                 addSize([1200, 0], [[728, 90], [920, 100]]).
#                 build();
#             bannersHome.adhesion_dsk.defineSizeMapping(adhesion_dsk_mapping);
#         });
#     }
#
#     googletag.pubads().collapseEmptyDivs();
#     googletag.pubads().setTargeting('metarefresh', metaRefreshKv);
#     googletag.pubads().setTargeting('tabIsActive', window.DFP.ads.tabIsActive);
#     googletag.pubads().setTargeting('adstest', testQueryString());
#     googletag.pubads().setTargeting('adtest', testQueryString());
#     googletag.pubads().setTargeting('seccion', "acumulado");
#     googletag.pubads().setTargeting('sitio', "lanacion");
#     googletag.pubads().enableSingleRequest();
#
#     googletag.pubads().disableInitialLoad();
#     navegg();
#     googletag.enableServices();
#
#
#     getBannersConfig();
# </script>
# <title>Últimas noticias de Argentina y el mundo - LA NACION</title>
# <script type="application/ld+json">
#     {
#     "@context": "http://schema.org",
#     "@type": "Person",
#     "name": "La Nacion",
#     "url": "https://www.lanacion.com.ar",
#     "sameAs": [
#     "https://www.facebook.com/lanacion/",
#     "https://www.instagram.com/lanacioncom/",
#     "https://twitter.com/LANACION"
#     ]
#     }
# </script>
# <script type="application/ld+json">
#     {
#     "@context": "http://schema.org",
#     "@type": "WebSite",
#     "url": "https://www.lanacion.com.ar/",
#     "potentialAction": {
#     "@type": "SearchAction",
#     "target": "https://buscar.lanacion.com.ar/{search_term}",
#     "query-input": "required name=search_term"
#     }
#     }
# </script>
# <link href="//static.glanacion.com/v2/ln/css/9a73e7733506870f84cc53713b859f69.min.css" rel="stylesheet"/>
# <!-- Google Tag Manager -->
# <script>(function (w, d, s, l, i) {
#     w[l] = w[l] || []; w[l].push({ 'gtm.start': new Date().getTime(), event: 'gtm.js' });
#     var f = d.getElementsByTagName(s)[0], j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
#     j.async = true; j.src = 'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
# })(window, document, 'script', 'dataLayer', 'GTM-GHV6');</script>
# <!-- End Google Tag Manager -->
# <script>window.render=true;</script>
# <script>(window.BOOMR_mq=window.BOOMR_mq||[]).push(["addVar",{"rua.upush":"false","rua.cpush":"false","rua.upre":"false","rua.cpre":"false","rua.uprl":"false","rua.cprl":"false","rua.cprf":"false","rua.trans":"","rua.cook":"false","rua.ims":"false","rua.ufprl":"false","rua.cfprl":"false","rua.isuxp":"false","rua.texp":"norulematch"}]);</script>
# <script>!function(a){var e="https://s.go-mpulse.net/boomerang/",t="addEventListener";if(""=="True")a.BOOMR_config=a.BOOMR_config||{},a.BOOMR_config.PageParams=a.BOOMR_config.PageParams||{},a.BOOMR_config.PageParams.pci=!0,e="https://s2.go-mpulse.net/boomerang/";if(window.BOOMR_API_key="FPXUV-CWEKR-ELG8D-URM4T-QZGQK",function(){function n(e){a.BOOMR_onload=e&&e.timeStamp||(new Date).getTime()}if(!a.BOOMR||!a.BOOMR.version&&!a.BOOMR.snippetExecuted){a.BOOMR=a.BOOMR||{},a.BOOMR.snippetExecuted=!0;var i,_,o,r=document.createElement("iframe");if(a[t])a[t]("load",n,!1);else if(a.attachEvent)a.attachEvent("onload",n);r.src="javascript:void(0)",r.title="",r.role="presentation",(r.frameElement||r).style.cssText="width:0;height:0;border:0;display:none;",o=document.getElementsByTagName("script")[0],o.parentNode.insertBefore(r,o);try{_=r.contentWindow.document}catch(O){i=document.domain,r.src="javascript:var d=document.open();d.domain='"+i+"';void(0);",_=r.contentWindow.document}_.open()._l=function(){var a=this.createElement("script");if(i)this.domain=i;a.id="boomr-if-as",a.src=e+"FPXUV-CWEKR-ELG8D-URM4T-QZGQK",BOOMR_lstart=(new Date).getTime(),this.body.appendChild(a)},_.write("<bo"+'dy onload="document._l();">'),_.close()}}(),"".length>0)if(a&&"performance"in a&&a.performance&&"function"==typeof a.performance.setResourceTimingBufferSize)a.performance.setResourceTimingBufferSize();!function(){if(BOOMR=a.BOOMR||{},BOOMR.plugins=BOOMR.plugins||{},!BOOMR.plugins.AK){var e=""=="true"?1:0,t="",n="ej623qaxe27suyfwumqa-f-cc6b777a2-clientnsv4-s.akamaihd.net",i={"ak.v":"31","ak.cp":"847416","ak.ai":parseInt("541075",10),"ak.ol":"0","ak.cr":41,"ak.ipv":4,"ak.proto":"http/1.1","ak.rid":"a4804465","ak.r":40955,"ak.a2":e,"ak.m":"a","ak.n":"essl","ak.bpcip":"34.125.173.0","ak.cport":50718,"ak.gh":"23.38.191.38","ak.quicv":"","ak.tlsv":"tls1.3","ak.0rtt":"","ak.csrc":"-","ak.acc":"reno","ak.t":"1622582048","ak.ak":"hOBiQwZUYzCg5VSAfCLimQ==...","ak.pv":"104","ak.dpoabenc":""};if(""!==t)i["ak.ruds"]=t;var _={i:!1,av:function(e){var t="http.initiator";if(e&&(!e[t]||"spa_hard"===e[t]))i["ak.feo"]=void 0!==a.aFeoApplied?1:0,BOOMR.addVar(i)},rv:function(){var a=["ak.bpcip","ak.cport","ak.cr","ak.csrc","ak.gh","ak.ipv","ak.m","ak.n","ak.ol","ak.proto","ak.quicv","ak.tlsv","ak.0rtt","ak.r","ak.acc","ak.t"];BOOMR.removeVar(a)}};BOOMR.plugins.AK={akVars:i,akDNSPreFetchDomain:n,init:function(){if(!_.i){var a=BOOMR.subscribe;a("before_beacon",_.av,null,null),a("onbeacon",_.rv,null,null),_.i=!0}return this},is_complete:function(){return!0}}}}()}(window);</script></head>
# <body>
# <!-- Google Tag Manager (noscript) -->
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-GHV6" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <!-- End Google Tag Manager (noscript) -->
# <input id="fechaGeneracionHome" type="hidden" value="01/06/2021 06:09:42 p.m."/>
# <div class="bn-megatop" id="container-megatop_dsk" style="display:none;">
# <button class="bajar_megatop" data-event="LinkClick" data-section="Megatop-home" id="btn-bajar-megatop_dsk">
#         PUBLICIDAD <span>BAJAR AL SITIO</span>
# </button>
# <div id="megatop_dsk">
# <script>
#                 var bannerName = "megatop_dsk";
#                 var result = false;
#                 if (bannerName == 'megatop_dsk') {
#                      result = showBannerResolution(bannerName) && window.innerWidth >= 1024;
#                 }
#                 else {
#                      result = showBannerResolution(bannerName) && window.innerWidth <= 639;
#                 }
#                 if (result) {
#                     const banner = bannersHome[bannerName];
#                     if (banner) {
#                         googletag.cmd.push(function () {
#                             googletag.display(bannerName);
#                             googletag.pubads().refresh([banner]);
#                         });
#                     } else {
#                         console.error(`Banner ${bannerName} no inicializado`);
#                     }
#                 }
#             </script>
# </div>
# </div>
# <div class="bn-megatop" id="container-megatop_mob" style="display:none;">
# <button class="bajar_megatop" data-event="LinkClick" data-section="Megatop-home" id="btn-bajar-megatop_mob">
#         PUBLICIDAD <span>BAJAR AL SITIO</span>
# </button>
# <div id="megatop_mob">
# <script>
#                 var bannerName = "megatop_mob";
#                 var result = false;
#                 if (bannerName == 'megatop_dsk') {
#                      result = showBannerResolution(bannerName) && window.innerWidth >= 1024;
#                 }
#                 else {
#                      result = showBannerResolution(bannerName) && window.innerWidth <= 639;
#                 }
#                 if (result) {
#                     const banner = bannersHome[bannerName];
#                     if (banner) {
#                         googletag.cmd.push(function () {
#                             googletag.display(bannerName);
#                             googletag.pubads().refresh([banner]);
#                         });
#                     } else {
#                         console.error(`Banner ${bannerName} no inicializado`);
#                     }
#                 }
#             </script>
# </div>
# </div>
# <div class="mod-banner --comercial" id="container-comercial_dsk" style="display:none;">
# <button class="com-button --primary --compact" data-event="LinkClick" data-section="Comercial-home" id="btn-bajar-comercial_dsk" type="button">CERRAR</button>
# <div class="com-banner" id="comercial_dsk">
# <script>
#                 var bannerName = "comercial_dsk";
#                 var result = false;
#                 if (bannerName == 'comercial_dsk') {
#                      result = showBannerResolution(bannerName) && window.innerWidth >= 1024;
#                 }
#                 else {
#                      result = showBannerResolution(bannerName) && window.innerWidth <= 639;
#                 }
#                 if (result) {
#                     const banner = bannersHome[bannerName];
#                     if (banner) {
#                         googletag.cmd.push(function () {
#                             googletag.display(bannerName);
#                             googletag.pubads().refresh([banner]);
#                         });
#                     } else {
#                         console.error(`Banner ${bannerName} no inicializado`);
#                     }
#                 }
#             </script>
# </div>
# </div>
# <div class="mod-banner --comercial" id="container-comercial_mob" style="display:none;">
# <button class="com-button --primary --compact" data-event="LinkClick" data-section="Comercial-home" id="btn-bajar-comercial_mob" type="button">CERRAR</button>
# <div class="com-banner" id="comercial_mob">
# <script>
#                 var bannerName = "comercial_mob";
#                 var result = false;
#                 if (bannerName == 'comercial_dsk') {
#                      result = showBannerResolution(bannerName) && window.innerWidth >= 1024;
#                 }
#                 else {
#                      result = showBannerResolution(bannerName) && window.innerWidth <= 639;
#                 }
#                 if (result) {
#                     const banner = bannersHome[bannerName];
#                     if (banner) {
#                         googletag.cmd.push(function () {
#                             googletag.display(bannerName);
#                             googletag.pubads().refresh([banner]);
#                         });
#                     } else {
#                         console.error(`Banner ${bannerName} no inicializado`);
#                     }
#                 }
#             </script>
# </div>
# </div>
# <div class="home" id="wrapper">
# <nav class="com-nav-mobile">
# <div class="row">
# <a class="col-3 item-foo" href="/">
# <i class="icon-home"></i>
# <p>Home</p>
# </a>
# <button class="onoff-dropdown col-3 item-foo" type="button">
# <i class="icon-section"></i>
# <p>Secciones</p>
# </button>
# <a class="col-3 item-foo" href="https://club.lanacion.com.ar/">
# <i class="icon-club"></i>
# <p>Club LA NACION</p>
# </a>
# <a class="col-3 item-foo" href="https://myaccount.lanacion.com.ar/mi-usuario">
# <i class="icon-user"></i>
# <p>Mi Cuenta</p>
# </a>
# </div>
# </nav>
# <div class="wrap-dropdown" role="button" tabindex="0">
# <div aria-label="overrlay" class="overlay onoff-dropdown" role="button" tabindex="0"></div>
# <div class="com-dropdown">
# <section class="header__dropdown row">
# <div class="logo__dropdown col-10"><a class="com-lanacion" href="/" title="LA NACION"><i class="logo-la-nacion"></i></a></div>
# <div class="close__dropdown onoff-dropdown col-2" role="button" tabindex="0" title="Cerrar"><i class="icon-close"></i></div>
# </section>
# <section class="menu__dropdown">
# <nav class="nav__dropdown">
# <ul class="list__nav first--nav">
# <li class="item__nav has--children item--disabled">
# <a class="link__item" data-event="LinkClick" data-section="MenuLN" href="https://www.lanacion.com.ar/ultimas-noticias/" title="Últimas Noticias">Últimas Noticias</a>
# <button class="button__item" type="button"><i class="icon-down"></i></button>
# <ul class="sublist__nav">
# <li class="item__nav "><a class="link__item" data-event="LinkClick" data-section="MenuLN" href="https://www.lanacion.com.ar/transito/" title="Tránsito">Tránsito</a></li>
# <li class="item__nav "><a class="link__item" data-event="LinkClick" data-section="MenuLN" href="http://servicios.lanacion.com.ar/pronostico-del-tiempo" title="Clima">Clima</a></li>
# <li class="item__nav "><a class="link__item" data-event="LinkClick" data-section="MenuLN" href="https://www.lanacion.com.ar/data/" title="LN DATA">LN DATA</a></li>
# </ul>
# </li>
# <li class="item__nav item--disabled">
# <a class="link__item" data-event="LinkClick" data-section="MenuLN" href="https://www.lanacion.com.ar/politica/" title="Política">Política</a>
# </li>
# <li class="item__nav has--children item--disabled">
# <a class="link__item" data-event="LinkClick" data-section="MenuLN" href="https://www.lanacion.com.ar/economia/" title="Economía">Economía</a>
# <button class="button__item" type="button"><i class="icon-down"></i></button>
# <ul class="sublist__nav">
# <li class="item__nav "><a class="link__item" data-event="LinkClick" data-section="MenuLN" href="https://www.lanacion.com.ar/dolar-hoy/" title="Dólar hoy">Dólar hoy</a></li>
# <li class="item__nav "><a class="link__item" data-event="LinkClick" data-section="MenuLN" href="https://www.lanacion.com.ar/economia/campo/" title="Campo">Campo</a></li>
# <li class="item__nav "><a class="link__item" data-event="LinkClick" data-section="MenuLN" href="https://www.lanacion.com.ar/propiedades/" title="Propiedades">Propiedades</a></li>
# <li class="item__nav "><a class="link__item" data-event="LinkClick" data-section="MenuLN" href="https://www.lanacion.com.ar/economia/comercio-exterior/" title="Comercio exterior">Comercio exterior</a></li>
# <li class="item__nav "><a class="link__item" data-event="LinkClick" data-section="MenuLN" href="https://www.lanacion.com.ar/autos/" title="Autos">Autos</a></li>
# <li class="item__nav "><a class="link__item" data-event="LinkClick" data-section="MenuLN" href="https://www.lanacion.com.ar/economia/indices" title="Índices">Índices</a></li>
# <li class="item__nav "><a class="link__item" data-event="LinkClick" data-section="MenuLN" href="https://www.lanacion.com.ar/economia/calculadora-ganancias-cuanto-se-pagara-2021-como-nid2561244/" title="Calculadora de ganancias">Calculadora de ganancias</a></li>
# </ul>
# </li>
# <li class="item__nav item--disabled">
# <a class="link__item" data-event="LinkClick" data-section="MenuLN" href="https://www.lanacion.com.ar/el-mundo/" title="El Mundo">El Mundo</a>
# </li>
# <li class="item__nav has--children item--disabled">
# <a class="link__item" data-event="LinkClick" data-section="MenuLN" href="https://www.lanacion.com.ar/sociedad/" title="Sociedad">Sociedad</a>
# <button class="button__item" type="button"><i class="icon-down"></i></button>
# <ul class="sublist__nav">
# <li class="item__nav "><a class="link__item" data-event="LinkClick" data-section="MenuLN" href="https://www.lanacion.com.ar/buenos-aires/" title="Buenos Aires">Buenos Aires</a></li>
# <li class="item__nav "><a class="link__item" data-event="LinkClick" data-section="MenuLN" href="https://www.lanacion.com.ar/seguridad/" title="Seguridad">Seguridad</a></li>
# <li class="item__nav "><a class="link__item" data-event="LinkClick" data-section="MenuLN" href="https://www.lanacion.com.ar/educacion/" title="Educación">Educación</a></li>
# <li class="item__nav "><a class="link__item" data-event="LinkClick" data-section="MenuLN" href="https://www.lanacion.com.ar/cultura/" title="Cultura">Cultura</a></li>
# <li class="item__nav "><a class="link__item" data-event="LinkClick" data-section="MenuLN" href="https://www.lanacion.com.ar/comunidad/" title="Comunidad">Comunidad</a></li>
# <li class="item__nav "><a class="link__item" data-event="LinkClick" data-section="MenuLN" href="https://www.lanacion.com.ar/salud/" title="Salud">Salud</a></li>
# <li class="item__nav "><a class="link__item" data-event="LinkClick" data-section="MenuLN" href="https://www.lanacion.com.ar/ciencia/" title="Ciencia">Ciencia</a></li>
# </ul>
# </li>
# <li class="item__nav has--children item--disabled">
# <a class="link__item" data-event="LinkClick" data-section="MenuLN" href="https://www.lanacion.com.ar/opinion/" title="Opinión">Opinión</a>
# <button class="button__item" type="button"><i class="icon-down"></i></button>
# <ul class="sublist__nav">
# <li class="item__nav "><a class="link__item" data-event="LinkClick" data-section="MenuLN" href="https://www.lanacion.com.ar/opinion/columnistas" title="Columnistas">Columnistas</a></li>
# <li class="item__nav "><a class="link__item" data-event="LinkClick" data-section="MenuLN" href="https://www.lanacion.com.ar/editoriales/" title="Editoriales">Editoriales</a></li>
# </ul>
# </li>
# <li class="item__nav has--children item--disabled">
# <a class="link__item" data-event="LinkClick" data-section="MenuLN" href="https://www.lanacion.com.ar/deportes/" title="Deportes">Deportes</a>
# <button class="button__item" type="button"><i class="icon-down"></i></button>
# <ul class="sublist__nav">
# <li class="item__nav "><a class="link__item" data-event="LinkClick" data-section="MenuLN" href="https://www.lanacion.com.ar/deportes/futbol/" title="Fútbol">Fútbol</a></li>
# <li class="item__nav "><a class="link__item" data-event="LinkClick" data-section="MenuLN" href="https://www.lanacion.com.ar/deportes/estadisticas/argentina-primera-anual-c2703/fixture#" title="Fixture">Fixture</a></li>
# <li class="item__nav "><a class="link__item" data-event="LinkClick" data-section="MenuLN" href="https://www.lanacion.com.ar/deportes/estadisticas/argentina-primera-anual-c2703/posiciones#" title="Posiciones">Posiciones</a></li>
# <li class="item__nav "><a class="link__item" data-event="LinkClick" data-section="MenuLN" href="https://www.lanacion.com.ar/deportes/rugby/" title="Rugby">Rugby</a></li>
# <li class="item__nav "><a class="link__item" data-event="LinkClick" data-section="MenuLN" href="https://www.lanacion.com.ar/deportes/tenis/" title="Tenis">Tenis</a></li>
# </ul>
# </li>
# <li class="item__nav has--children item--disabled">
# <a class="link__item" data-event="LinkClick" data-section="MenuLN" href="https://www.lanacion.com.ar/lifestyle/" title="Lifestyle">Lifestyle</a>
# <button class="button__item" type="button"><i class="icon-down"></i></button>
# <ul class="sublist__nav">
# <li class="item__nav "><a class="link__item" data-event="LinkClick" data-section="MenuLN" href="https://www.lanacion.com.ar/moda-y-belleza/" title="Moda y belleza">Moda y belleza</a></li>
# <li class="item__nav "><a class="link__item" data-event="LinkClick" data-section="MenuLN" href="https://www.lanacion.com.ar/turismo/" title="Turismo">Turismo</a></li>
# <li class="item__nav "><a class="link__item" data-event="LinkClick" data-section="MenuLN" href="https://www.lanacion.com.ar/tecnologia/" title="Tecnología">Tecnología</a></li>
# <li class="item__nav "><a class="link__item" data-event="LinkClick" data-section="MenuLN" href="https://www.lanacion.com.ar/horoscopo" title="Horóscopo">Horóscopo</a></li>
# <li class="item__nav "><a class="link__item" data-event="LinkClick" data-section="MenuLN" href="https://www.lanacion.com.ar/feriados" title="Feriados">Feriados</a></li>
# <li class="item__nav "><a class="link__item" data-event="LinkClick" data-section="MenuLN" href="http://servicios.lanacion.com.ar/loterias" title="Loteria y quinielas">Loteria y quinielas</a></li>
# <li class="item__nav "><a class="link__item" data-event="LinkClick" data-section="MenuLN" href="https://www.lanacion.com.ar/recetas/" title="Cocina y recetas">Cocina y recetas</a></li>
# <li class="item__nav "><a class="link__item" data-event="LinkClick" data-section="MenuLN" href="https://www.lanacion.com.ar/lifestyle/cuales-son-podcast-la-nacion-nid2165046" title="Podcasts">Podcasts</a></li>
# <li class="item__nav "><a class="link__item" data-event="LinkClick" data-section="MenuLN" href="https://www.lanacion.com.ar/sudoku-online" title="Sudoku">Sudoku</a></li>
# </ul>
# </li>
# <li class="item__nav has--children item--disabled">
# <a class="link__item" data-event="LinkClick" data-section="MenuLN" href="https://www.lanacion.com.ar/espectaculos/" title="Espectáculos">Espectáculos</a>
# <button class="button__item" type="button"><i class="icon-down"></i></button>
# <ul class="sublist__nav">
# ...
# <!--Crear Parcial para Volanta-->
# <em class="com-volanta">Dumbo.</em>
#         El narco que se mudó a Martínez y dejó el mate tibio para poder escapar
#     </a>
# </h2>
# <!--Crear Parcial para Bajada-->
# <!--Crear Parcial para Autor-->
# <strong class="com-author">
# <a href="https://www.lanacion.com.ar/seguridad/dumbo-el-capo-narco-que-se-mudo-a-martinez-y-dejo-el-mate-tibio-para-poder-escapar-de-la-policia-nid01062021/" title="Por Gabriel Di Nicola">Por Gabriel Di Nicola</a>
# </strong>
# </div>
# </article>
# <article class="mod-article w-100-mobile --m firma-autor toi8752 nid2717114" data-id="2717114" data-notaid="2717114" data-pos="8752" data-source="editor">
# <div class="com-media">
# <a href="https://www.lanacion.com.ar/sociedad/covid-19-avanza-en-el-instituto-leloir-otra-vacuna-argentina-nid01062021/" title="Avanza en el Instituto Leloir otra vacuna argentina">
# <picture>
# <source alt="Avanza en el Instituto Leloir otra vacuna argentina" media="(min-width: 75.000em)" srcset="//bucket1.glanacion.com/anexos/fotos/11/3786011h186.jpg">
# <source alt="Avanza en el Instituto Leloir otra vacuna argentina" media="(min-width: 48.000em)" srcset="//bucket1.glanacion.com/anexos/fotos/11/3786011h230.jpg">
# <source alt="Avanza en el Instituto Leloir otra vacuna argentina" media="(min-width: 21.875em)" srcset="//bucket1.glanacion.com/anexos/fotos/11/3786011h513.jpg">
# <source alt="Avanza en el Instituto Leloir otra vacuna argentina" media="(max-width: 21.874em)" srcset="//bucket1.glanacion.com/anexos/fotos/11/3786011h234.jpg">
# <img alt="Avanza en el Instituto Leloir otra vacuna argentina" loading="lazy" srcset=""/>
# </source></source></source></source></picture>
# </a>
# </div>
# <div class="com-description">
# <!--Crear Parcial para Chapita-->
# <h2 class="com-title">
# <a href="https://www.lanacion.com.ar/sociedad/covid-19-avanza-en-el-instituto-leloir-otra-vacuna-argentina-nid01062021/" title="Avanza en el Instituto Leloir otra vacuna argentina">
# <!--Crear Parcial para Volanta-->
# <em class="com-volanta">Covid-19.</em>
#         Avanza en el Instituto Leloir otra vacuna argentina
#     </a>
# </h2>
# <!--Crear Parcial para Bajada-->
# <!--Crear Parcial para Autor-->
# <strong class="com-author">
# <a href="https://www.lanacion.com.ar/sociedad/covid-19-avanza-en-el-instituto-leloir-otra-vacuna-argentina-nid01062021/" title="Por Nora Bär">Por Nora Bär</a>
# </strong>
# </div>
# </article>
# <article class="mod-article w-100-mobile --m toi8753 nid2716835" data-id="2716835" data-notaid="2716835" data-pos="8753" data-source="editor">
# <div class="com-media">
# <a href="https://www.lanacion.com.ar/deportes/futbol/la-generosa-despedida-de-sergio-aguero-con-los-empleados-del-manchester-city-mas-de-60-relojes-nid01062021/" title="Los costosos regalos del Kun Agüero a los empleados del City">
# <picture>
# <source alt="Los costosos regalos del Kun Agüero a los empleados del City" media="(min-width: 75.000em)" srcset="//bucket1.glanacion.com/anexos/fotos/90/3785590h186.jpg">
# <source alt="Los costosos regalos del Kun Agüero a los empleados del City" media="(min-width: 48.000em)" srcset="//bucket1.glanacion.com/anexos/fotos/90/3785590h230.jpg">
# <source alt="Los costosos regalos del Kun Agüero a los empleados del City" media="(min-width: 21.875em)" srcset="//bucket1.glanacion.com/anexos/fotos/90/3785590h513.jpg">
# <source alt="Los costosos regalos del Kun Agüero a los empleados del City" media="(max-width: 21.874em)" srcset="//bucket1.glanacion.com/anexos/fotos/90/3785590h234.jpg">
# <img alt="Los costosos regalos del Kun Agüero a los empleados del City" loading="lazy" srcset=""/>
# </source></source></source></source></picture>
# </a>
# </div>
# <div class="com-description">
# <!--Crear Parcial para Chapita-->
# <h2 class="com-title">
# <a href="https://www.lanacion.com.ar/deportes/futbol/la-generosa-despedida-de-sergio-aguero-con-los-empleados-del-manchester-city-mas-de-60-relojes-nid01062021/" title="Los costosos regalos del Kun Agüero a los empleados del City">
# <!--Crear Parcial para Volanta-->
# <em class="com-volanta">Un gesto increíble.</em>
#         Los costosos regalos del Kun Agüero a los empleados del City
#     </a>
# </h2>
# <!--Crear Parcial para Bajada-->
# <!--Crear Parcial para Autor-->
# </div>
# </article>
# </div>
# </section>
# <aside class="com-banner --middle" id="billboard_dsk" style="display:none">
# </aside><aside class="com-banner --middle" id="middle_1_tab" style="display:none">
# </aside><aside class="com-banner --middle" id="caja2_mob" style="display:none">
# </aside>
# <div data-module="tema_1" data-module-js="//static.glanacion.com/v2/ln/js/module/bloque2-ad41e81.min.js"></div>
# <div class="row-gap-tablet-3 --ads">
# <aside class="com-banner --square" id="caja1_dsk" style="display:none">
# </aside><aside class="com-banner clubln" id="caja_producto1_dsk" style="display:none">
# </aside><aside class="com-banner --square" id="caja2_dsk" style="display:none">
# </aside>
# </div>
# <div class="row-gap-tablet-2 --ads">
# <aside class="com-banner --square" id="caja1_tab" style="display:none">
# </aside><aside class="com-banner --square" id="caja2_tab" style="display:none">
# </aside>
# </div>
# <aside class="com-banner --middle" id="caja3_mob" style="display:none">
# </aside>
# <div data-module="tema_2"></div>
# <div data-module="anexo_3"></div>
# <aside class="com-banner --middle" id="cinturon_1_dsk" style="display:none">
# </aside><aside class="com-banner --middle" id="caja4_mob" style="display:none">
# </aside><aside class="com-banner --middle" id="middle_2_tab" style="display:none">
# </aside>
# <div data-module="tema_3"></div>
# <aside class="com-banner --middle" id="cinturon_2_dsk" style="display:none">
# </aside><aside class="com-banner --middle" id="caja5_mob" style="display:none">
# </aside>
# <div data-module="opinion" data-module-js="//static.glanacion.com/v2/ln/js/module/bloque3-372b2d1.min.js"></div>
# <div class="row-gap-tablet-3 --ads">
# <aside class="com-banner --square" id="caja3_dsk" style="display:none">
# </aside><aside class="com-banner clubln" id="caja_producto2_dsk" style="display:none">
# </aside><aside class="com-banner --square" id="caja4_dsk" style="display:none">
# </aside>
# </div>
# <div class="row-gap-tablet-2 --ads">
# <aside class="com-banner --square" id="caja3_tab" style="display:none">
# </aside><aside class="com-banner --square" id="caja4_tab" style="display:none">
# </aside>
# </div>
# <div data-module="tema_4"></div>
# <aside class="com-banner --middle" id="middle1_dsk" style="display:none">
# </aside>
# <div data-module="tema_5"></div>
# <div data-module="tema_6"></div>
# </section>
# <aside class="sidebar__aside">
# <aside class="com-banner --megalateral" id="megalateral_dsk" style="display:none">
# <script>
#             {
#                 const bannerName = "megalateral_dsk";
#                 var result = showBannerResolution(bannerName);
#                 if (showBannerResolution(bannerName)) {
#                     const banner = bannersHome[bannerName];
#                     if (banner) {
#                         googletag.cmd.push(function () {
#                             googletag.display(bannerName);
#                             googletag.pubads().refresh([banner]);
#                         });
#                     } else {
#                         console.error(`Banner ${bannerName} no inicializado`);
#                     }
#                 }
#             }
#         </script>
# </aside>
# </aside>
# </section>
# <section class="lay">
# <div data-module="mas-leidas"></div>
# <div data-module="comercial_1"></div>
# </section>
# <section class="lay-sidebar">
# <section class="sidebar__main">
# <div data-module="tema_7" data-module-js="//static.glanacion.com/v2/ln/js/module/bloque4-11c31d4.min.js"></div>
# <div data-module="tema_8"></div>
# <div data-module="comercial_2"></div>
# <div data-module="tema_9"></div>
# <div data-module="tema_10"></div>
# <div data-module="tema_11"></div>
# </section>
# <aside class="sidebar__aside">
# <aside class="com-banner --megalateral" id="megalateral2_dsk" style="display:none">
# </aside>
# </aside>
# </section>
# <section class="lay-sidebar">
# <section class="sidebar__main">
# <div data-module="tema_12" data-module-js="//static.glanacion.com/v2/ln/js/module/bloque5-6719257.min.js"></div>
# <div data-module="tema_13"></div>
# <div data-module="tema_14"></div>
# <div data-module="tema_15"></div>
# <div data-module="tema_16"></div>
# <div data-module="tema_17"></div>
# <div data-module="tema_18"></div>
# <div data-module="te-puede-interesar"></div>
# <div class="notificacion-modal" id="notificacion-modal">
# <a class="com-lanacion" href="/" title="LA NACION"><i class="logo-la-nacion"></i></a>
# <p class="mens">¿Querés recibir notificaciones de alertas?</p>
# <div class="btns">
# <button id="notificacion-no" type="button">No, gracias</button>
# <button id="notificacion-si" type="button">Aceptar</button>
# </div>
# </div>
# <div class="notificacion-modal" id="notificacion-error-modal">
# <div class="logo">
# <svg enable-background="new 0 0 718 77" height="77px" id="Layer_1" version="1.1" viewbox="0 0 718 77" width="718px" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
# <g>
# <path d="M65.001,49.539c0,16.418-12.178,20.676-27.445,20.676h-2.734V7.918h12.803V2.959H1.15v4.959h11.623v62.297H1.15v4.964
#                                 h69.598V46.427h-5.746V49.539z"></path>
# <path d="M125.537,3.069h-8.705L87.087,64.1c-1.721,3.392-4.396,6.115-9.939,6.115h-2.351v4.964h27.898v-4.964H97.65
#                                 c-2.926,0-5.469-0.372-5.469-3.757c0-1.146,0.598-2.252,1.025-3.078l3.98-8.318h30.166l7.572,15.153h-11.139v4.964h45.971v-4.964
#                                 h-9.664L125.537,3.069z M99.599,50.14l12.163-24.51h0.991l12.18,24.51H99.599z"></path>
# <path d="M301.664,2.959h-28.69v4.959h3.466c5.786,0,8.93,1.896,8.93,5.83v31.88h-0.266L248.087,2.959h-33.571v4.959h1.982
#                                 c4.362,0,8.819,3.177,8.819,8.075v46.852c0,6.247-3.797,7.37-7.838,7.37h-1.445h-1.921v4.964h28.634v-4.964h-2.246
#                                 c-7.264,0-10.153-0.991-10.153-6.835V17.021h0.263l50.272,58.158h9.585V13.43c0-2.574,2.439-5.512,8.377-5.512h2.818V2.959z"></path>
# <path d="M351.055,3.069h-8.732L312.548,64.1c-1.684,3.392-4.377,6.115-9.937,6.115h-2.36v4.964h27.988v-4.964h-5.146
#                                 c-2.899,0-5.433-0.372-5.433-3.757c0-1.146,0.609-2.252,1.008-3.078l4.005-8.318h30.209l7.507,15.153h-11.137v4.964h45.954v-4.964
#                                 h-9.646L351.055,3.069z M325.123,50.14l12.114-24.51h1.04l12.125,24.51H325.123z"></path>
# <path d="M439.029,71.773c-17.453,0-20.705-15.069-20.705-32.594c0-18.248,3.611-33.132,21.137-33.132
#                                 c14.004,0,19.795,12.213,21.924,22.639h5.701V3.069h-3.787c-0.117,2.191-0.748,4.151-3.625,4.151c-2.824,0-8.229-6.1-23.582-6.1
#                                 c-20.635,0-41.961,17.326-41.961,38.059c0,21.049,22.047,37.82,43.729,37.82c16.932,0,30.016-9.829,30.016-27.461h-6.002
#                                 C461.873,62.377,452.666,71.773,439.029,71.773z"></path>
# <polygon points="478.668,7.918 490.299,7.918 490.299,70.215 478.668,70.215 478.668,75.179 523.994,75.179 523.994,70.215
#                                 512.311,70.215 512.311,7.918 523.994,7.918 523.994,2.959 478.668,2.959 	"></polygon>
# <path d="M576.51,1.121c-21.391,0-43.041,16.622-43.041,37.949c0,21.344,21.65,37.93,43.041,37.93
#                                 c21.273,0,43.301-16.586,43.301-37.93C619.811,17.743,597.783,1.121,576.51,1.121z M576.611,72.093
#                                 c-16.943,0-19.162-16.312-19.162-33.022c0-16.804,2.293-33.022,19.162-33.022c17.004,0,19.193,16.087,19.193,33.022
#                                 C595.805,55.891,593.615,72.093,576.611,72.093z"></path>
# <path d="M685.438,2.959v4.959h3.512c5.76,0,8.898,1.896,8.898,5.83v31.88h-0.33L660.529,2.959h-33.568v4.959h1.986
#                                 c4.385,0,8.859,3.177,8.859,8.075v46.852c0,6.247-3.795,7.37-7.816,7.37h-1.428h-1.957v4.964h28.592v-4.964h-2.254
#                                 c-7.316,0-10.15-0.991-10.15-6.835V17.021h0.238l50.281,58.158h9.588V13.43c0-2.574,2.508-5.512,8.404-5.512h2.846V2.959H685.438z"></path>
# </g>
# </svg>
# </div>
# <p class="mens">Ha ocurrido un error de conexión</p>
# <div class="btns">
# <button id="notificacion-error-btn" type="button">Cerrar</button>
# </div>
# </div>
# <div class="notificacion-modal" id="notificacion-modal-pwa">
# <a class="com-lanacion" href="/" title="LA NACION"><i class="logo-la-nacion"></i></a>
# <p class="mens">Descargá la aplicación de LA NACION. Es rápida y liviana.</p>
# <div class="btns">
# <button id="notificacion-pwa-no" type="button">No, gracias</button>
# <button id="notificacion-pwa-si" type="button">Aceptar</button>
# </div>
# </div>
# <section class="row">
# <section class="row">
# <div class="mod-tags">
# <div class="com-header">
#         Temas del día:
#     </div>
# <ul class="com-secondary-tag">
# <li>
# <a href="/tema/coronavirus-en-la-argentina-tid67682">Coronavirus En La Argentina</a>
# </li>
# <li>
# <a href="/tema/actualidad-politica-tid56691">Actualidad Política</a>
# </li>
# <li>
# <a href="/tema/narcotrafico-tid29386">Narcotráfico</a>
# </li>
# <li>
# <a href="/tema/coronavirus-tid67578">Coronavirus</a>
# </li>
# <li>
# <a href="/tema/futbol-internacional-tid46866">Fútbol Internacional</a>
# </li>
# <li>
# <a href="/tema/violencia-de-genero-tid47009">Violencia De Género</a>
# </li>
# <li>
# <a href="/tema/roland-garros-tid15580">Roland Garros</a>
# </li>
# <li>
# <a href="/tema/elecciones-2021-tid68501">Elecciones 2021</a>
# </li>
# <li>
# <a href="/tema/a-fondo-tid57485">A Fondo</a>
# </li>
# <li>
# <a href="/tema/hoy-tid67696">Hoy</a>
# </li>
# </ul>
# </div>
# </section>
# </section>
# </section>
# <aside class="sidebar__aside">
# <aside class="com-banner --megalateral" id="megalateral3_dsk" style="display:none">
# </aside>
# </aside>
# </section>
# </main>
# <div data-module="footer"></div>
# </div>
# <iframe height="0" id="iLogout" name="iLogout" width="0"></iframe>
# <noscript>
# <img src="http://b.scorecardresearch.com/p?c1=2&amp;c2=6906398&amp;cv=2.0&amp;cj=1"/>
# </noscript>
# <script>
#     var _comscore = _comscore || [];
#     _comscore.push({ c1: "2", c2: "6906398" });
#     (function() {
#         var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#         s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#         el.parentNode.insertBefore(s, el);
#     })();
# </script>
# <script id="" type="text/javascript">
#     (function (w, d, s, p, v, e, r) {
#     w['$igniter_var'] = v; w[v] = w[v] || function () {
#         (w[v].q = w[v].q || []).push(
#             arguments)
#     }; w[v].l = 1 * new Date(); e = d.createElement(s), r = d.getElementsByTagName(s)[0]; e.async = 1;
#         e.src = p + '?ts=' + (+new Date() / 3600000 | 0);
#         r.parentNode.insertBefore(e, r)
#     })(window, document, 'script', '//cdn.petametrics.com/8561ps8ov66e7mim.js', '$p');
#
#     var customConfig = {
#         config: {
#             inventory: {
#                 mandatoryOpenGraphFeatures: ["title", "type"],
#                 features: [{
#                     name: "id",
#                     type: "attribute",
#                     selector: "link[rel=canonical]",
#                     attribute: "href",
#                     transform: function (value) {
#                         return value.replace('https://www.lanacion.com.ar/', '').split('-')[0];
#                     }
#                 }]
#             },
#             sdk: {
#                 requestFields: ['url', 'title', 'image', 'id']
#             }
#         }
#     }
#
#     $p("init", "8561ps8ov66e7mim", customConfig);
#
#     if (dataLayer[0].usuarioLogeado !== "no") {
#         $p("setUserId", dataLayer[0].userId);
#     }
#
#     $p("send", "pageview");
# </script>
# <script src="//static.glanacion.com/v2/ln/js/commons-d2738a2.min.js"></script>
# <script src="//static.glanacion.com/v2/ln/js/home-add9f09.min.js"></script>
# <div data-bannerdisabled="False"></div>
# <div data-bannerisdfp="True"></div>
# </body>
# </html>>

# %% [markdown]
# Ahora todo lo que queda es encontrar los elementos que nos interese.
# ¿Cómo los identificamos? Es un trabajo de ida y vuelta, y prueba y error, así que a no frustrarse si no sale de entrada. Los pasos a seguir son:
# - Ir a la página que queremos scrappear y con el botón derecho del mouse poner "inspeccionar elemento" sobre el sector de la página que nos interese.
# - Luego podemos identificarlo por su *tag* o por algún atributo que nos permita identificarlo mejor, como por ejemplo, la clase (*class*).
# - A veces puede ser más conveniente no apuntarle al elemento que nos interesa sino a un nodo superior (que lo contenga) y a partir de ahí navegar hacia dentro.
#
# Investigando la página del diario La Nación encontramos que los recuadros correspondientes a los títulos y enlaces de las principales notas están dentro de bloques con atributo:
# ~~~
# <... class = "com-title">
# ~~~
# Como observamos que el tag puede ser *h1* o *h2*, vamos a tratar de no especificar el *tag* para no perdernos nada. Buscamos entonces todos los elementos que cumplan el requisito de la clase sin especificar el *tag*:

# %%
# Creamos una lista con los elementos cuya clase = "com-title" con cualquier tag
elements = soup.find_all(attrs = {"class": "com-title"})

# %% [markdown]
# Vemos en qué consiste la lista de elementos:

# %%
print(elements)
# Out:
# [<h1 class="com-title">
# <a href="https://www.lanacion.com.ar/sociedad/coronavirus-en-la-argentina-reportan-641-muertos-y-35355-nuevos-casos-nid01062021/" title="Reportan 641 muertos y 35.355 nuevos casos de Covid">
# <!--Crear Parcial para Volanta-->
# <em class="com-volanta">Pandemia.</em>
#         Reportan 641 muertos y 35.355 nuevos casos de Covid
#     </a>
# </h1>, <h2 class="com-title">
# <a href="https://www.lanacion.com.ar/el-mundo/la-trama-mafiosa-detras-de-la-venta-de-terrenos-en-un-exclusivo-barrio-de-jose-ignacio-nid01062021/" title="La trama detrás de la venta de terrenos de argentinos en José Ignacio">
# <!--Crear Parcial para Volanta-->
# <em class="com-volanta">Mafia.</em>
#         La trama detrás de la venta de terrenos de argentinos en José Ignacio
#     </a>
# </h2>, <h2 class="com-title">
# <a href="https://www.lanacion.com.ar/politica/murio-el-consultor-y-analista-politico-jorge-giacobbe-nid01062021/" title="Murió el consultor Jorge Giacobbe">
# <!--Crear Parcial para Volanta-->
# <em class="com-volanta">Analista político.</em>
#         Murió el consultor Jorge Giacobbe
#     </a>
# </h2>, <h2 class="com-title">
# <a href="https://www.lanacion.com.ar/seguridad/dumbo-el-capo-narco-que-se-mudo-a-martinez-y-dejo-el-mate-tibio-para-poder-escapar-de-la-policia-nid01062021/" title="El narco que se mudó a Martínez y dejó el mate tibio para poder escapar">
# <!--Crear Parcial para Volanta-->
# <em class="com-volanta">Dumbo.</em>
#         El narco que se mudó a Martínez y dejó el mate tibio para poder escapar
#     </a>
# </h2>, <h2 class="com-title">
# <a href="https://www.lanacion.com.ar/sociedad/covid-19-avanza-en-el-instituto-leloir-otra-vacuna-argentina-nid01062021/" title="Avanza en el Instituto Leloir otra vacuna argentina">
# <!--Crear Parcial para Volanta-->
# <em class="com-volanta">Covid-19.</em>
#         Avanza en el Instituto Leloir otra vacuna argentina
#     </a>
# </h2>, <h2 class="com-title">
# <a href="https://www.lanacion.com.ar/deportes/futbol/la-generosa-despedida-de-sergio-aguero-con-los-empleados-del-manchester-city-mas-de-60-relojes-nid01062021/" title="Los costosos regalos del Kun Agüero a los empleados del City">
# <!--Crear Parcial para Volanta-->
# <em class="com-volanta">Un gesto increíble.</em>
#         Los costosos regalos del Kun Agüero a los empleados del City
#     </a>
# </h2>]

# %% [markdown]
# Cada elemento tiene por ejemplo enlace a la página (*href*) de la nota que va a estar contenido dentro de un *tag < a >*.
# Entonces lo que hacemos es iterar sobre todos los elementos y encontrar el *tag a* y pedirle el valor del atributo *href*:

# %%
# Iteramos sobre los elementos
# Hacemos un try ... except ... por si alguno de los elementos no tiene enlace 
# (puede ser que estemos agarrando más cosas de las que nos interesa)
urls = []
for element in elements:
  try:
    urls.append(element.find('a')['href'])
  except:
    pass

print(urls)
# Out:
# ['https://www.lanacion.com.ar/sociedad/coronavirus-en-la-argentina-reportan-641-muertos-y-35355-nuevos-casos-nid01062021/', 'https://www.lanacion.com.ar/el-mundo/la-trama-mafiosa-detras-de-la-venta-de-terrenos-en-un-exclusivo-barrio-de-jose-ignacio-nid01062021/', 'https://www.lanacion.com.ar/politica/murio-el-consultor-y-analista-politico-jorge-giacobbe-nid01062021/', 'https://www.lanacion.com.ar/seguridad/dumbo-el-capo-narco-que-se-mudo-a-martinez-y-dejo-el-mate-tibio-para-poder-escapar-de-la-policia-nid01062021/', 'https://www.lanacion.com.ar/sociedad/covid-19-avanza-en-el-instituto-leloir-otra-vacuna-argentina-nid01062021/', 'https://www.lanacion.com.ar/deportes/futbol/la-generosa-despedida-de-sergio-aguero-con-los-empleados-del-manchester-city-mas-de-60-relojes-nid01062021/']

# %%
print(len(urls))
# Out:
# 6

# %% [markdown]
# Ya tenemos enlaces de páginas (¿son todos los que vemos cuando abrimos la página? ¿No habrá contenido dinámico que nos estamos perdiendo?).

# %% [markdown]
# ### Scrappeo de la paǵina de un artículo

# %% [markdown]
# Veamos si podemos extraer contenido de las notas cuyos enlaces extraímos. La idea es la misma: ir a la página e inspeccionar los elementos que nos interese. Cuando las páginas corresponden a la misma plataforma es usual que la información se encuentre en el mismo lugar, por lo que aprendamos de una sola paǵina podemos quizás extrapolarlo a otras.
#
# Agarremos un *url* (por ejemplo, alguno de los de arriba) y generemos la sopa:

# %%
# Url de interés
url = 'https://www.lanacion.com.ar/sociedad/coronavirus-en-la-argentina-reportan-641-muertos-y-35355-nuevos-casos-nid01062021/'

# Hacemos un request a dicha página
response = requests.get(url)

# Creamos la sopa para manipular
soup = BS(response.content)

# %% [markdown]
# Identificando dónde está el título de la nota (eso de vuelta, inspeccionando el elemento asociado), podemos extraer el texto:

# %%
# Buscamos el elemento cuya clase indentificamos como correspondiente al título de la nota
title = soup.find(attrs = {"class": "com-title --threexl"})
print(title.text)
# Out:
# Coronavirus en la Argentina: reportan 641 muertos y 35.355 nuevos casos

# %% [markdown]
# Fecha de la nota:

# %%
date = soup.find(attrs = {"class": "com-date --twoxs"}).text
print(date)
# Out:
# 1 de junio de 2021

# %% [markdown]
# O, urgando un poco más en el código HTML, podemos extraer la fecha mejor formateada (notar otra manera de buscar cosas con BS):

# %%
# Buscamos un tag del tipo "meta", cuyo atributo "property" tiene valor "article:published_time"
# A este tag le sacamos el valor que toma el atributo "content"
datetime = soup.find("meta", attrs = {"property": "article:published_time"})['content']
print(datetime)
# Out:
# 2021-06-01T20:17:28.924Z

# %% [markdown]
# Veamos la descripción de la nota, que podemos encontrarla en:

# %%
description = soup.find(attrs = {"class": "com-subhead --bajada --m-xs"}).text
print(description)
# Out:
# Los fallecidos en el país se acercan a los 79.000, mientras los internados en Unidades de Terapia Intensiva continúan en alza

# %% [markdown]
# Por último veamos el cuerpo de la nota. Encontramos un nodo padre del tipo *section* cuya clase es *cuerpo__nota* (notar que tenemos que escribir todo exactamente como lo vemos en el código de la página. Cualquier error de tipeo va a resultar en que no nos devuelva nada):

# %%
# Buscamos un tag del tipo "section", cuyo atributo "class" tiene valor "cuerpo__nota"
body = soup.find("section", attrs = {"class": "cuerpo__nota"})

# %% [markdown]
# Usualmente, los párrafos están dentro de tags denominados *p*. Por lo que buscamos todos estos dentro del bloque asociado al cuerpo de la nota:

# %%
# Párrafos usualmente dentro de tags p
paragraphs = body.find_all('p')

print(paragraphs)
# Out:
# [<p class="com-paragraph --capital --s">El Gobierno informó que en las últimas 24 horas se reportaron<strong> 35.355 nuevos casos de Covid y 641 fallecidos. </strong>De esta manera, el país ya cuenta con 78.733 muertos.</p>, <p class="com-paragraph --s">Con los 35.355 casos positivos de coronavirus Covid-19, según los datos publicados en la Sala de Situación Coronavirus online del Ministerio de Salud de la Nación, <strong>las personas que dieron positivo por el virus SARS-CoV-2 en el país desde el inicio de la pandemia son 3.817.139. </strong>De este número, ya se recuperaron <strong>3.381.337 y los que aún cursan la enfermedad son 357.069.</strong></p>, <p class="com-paragraph --s">Las provincias que reportaron contagios fueron:</p>, <p class="com-paragraph --s">Entre los muertos ingresados en el Sistema Naciona de Vigilancia en Salud (SNVS), <strong>seis personas residentes en la provincia de Buenos Aires, una en la ciudad de Buenos Aires, una en Misiones, una en Mendoza y una en Entre Ríos no presentaban datos de género. Del resto, 367 eran hombres que vivían en:</strong></p>, <p class="com-paragraph --s">En tanto, las mujeres <strong>eran 264 y vivían en:</strong></p>, <p class="com-paragraph --s">Por otra parte, <strong>ayer eran 7417 las personas que cursaban la enfermedad </strong>en Unidades de Terapia Intensiva (UTI), nuevo récord de la pandemia. La ocupación de camas UTI, más allá de la dolencia que explique la internación del paciente, a nivel nacional promedia el 78,1%, mientras que en el AMBA llega al 77,3%.</p>, <p class="com-paragraph --s">Además, se informó que ayer<strong> fueron procesados 107.697 testeos y desde el inicio del brote se realizaron 14.067.367 pruebas diagnósticas </strong>para esta enfermedad.</p>, <p class="com-paragraph --s"><a class="com-link" data-reactroot="" href="https://www.argentina.gob.ar/coronavirus/vacuna/aplicadas" rel="nonoopener noreferrer" target="_blank" title="En el “Monitor Público de Vacunación”,">En el “Monitor Público de Vacunación”,</a> que <strong>comenzó a difundir el Gobierno en febrero, se indica que, con datos hasta el mediodía, se distribuyeron 15.373.890 dosis.</strong> De ese total, 12.497.078 ya se aplicaron: 9.667.003 personas recibieron una sola dosis y 2.830.075 completaron el proceso de vacunación.</p>, <p class="com-paragraph --s">Por otra parte, el Ministerio de Salud de la Nación <strong>informó que comenzará mañana la distribución en todo el país de una partida de 2.119.000 vacunas Astrazeneca </strong>que llegarán a todas las jurisdicciones. </p>, <p class="com-paragraph --s">De acuerdo al criterio dispuesto en base a la cantidad de población de cada distrito, las dosis para cada provincia serán:</p>, <p class="com-paragraph --s">Las dosis que se repartirán son las que <strong>llegaron ayer al Aeropuerto de Ezeiza con las vacunas cuyo principio activo se produjo en la Argentina y que se suman a las 2.785.200 dosis que arribaron la semana pasada</strong>, entre las Sputnik V y las desarrolladas en conjunto por la Universidad de Oxford y AstraZeneca que fueron adquiridas tanto por el mecanismo Covax de la OMS como en un acuerdo con la empresa farmacéutica británica.</p>, <p class="com-paragraph --s"><strong>La Argentina ya recibió 17.631.945 vacunas: </strong>8.115.745 corresponden a Sputnik V (6.975.585 del componente 1 y 1.140.160 del componente 2), 4.000.000 a Sinopharm, 580.000 a Astrazeneca - Covishield, 1.944.000 a Astrazeneca por el mecanismo Covax y 2.992.200 a las de Astrazeneca y Oxford cuyo principio activo se produjo en la Argentina.</p>, <p class="com-paragraph "><span class="com-text" data-reactroot=""></span></p>]

# %%
# Iteramos para todo párrafo y vemos el texto contenido
# Podemos hacer una lista y concatenar todo con un salto de línea
texts = []
for p in paragraphs:
  texts.append(p.text)

body_text = '\n'.join(texts)

print(body_text)
# Out:
# El Gobierno informó que en las últimas 24 horas se reportaron 35.355 nuevos casos de Covid y 641 fallecidos. De esta manera, el país ya cuenta con 78.733 muertos.
# Con los 35.355 casos positivos de coronavirus Covid-19, según los datos publicados en la Sala de Situación Coronavirus online del Ministerio de Salud de la Nación, las personas que dieron positivo por el virus SARS-CoV-2 en el país desde el inicio de la pandemia son 3.817.139. De este número, ya se recuperaron 3.381.337 y los que aún cursan la enfermedad son 357.069.
# Las provincias que reportaron contagios fueron:
# Entre los muertos ingresados en el Sistema Naciona de Vigilancia en Salud (SNVS), seis personas residentes en la provincia de Buenos Aires, una en la ciudad de Buenos Aires, una en Misiones, una en Mendoza y una en Entre Ríos no presentaban datos de género. Del resto, 367 eran hombres que vivían en:
# En tanto, las mujeres eran 264 y vivían en:
# Por otra parte, ayer eran 7417 las personas que cursaban la enfermedad en Unidades de Terapia Intensiva (UTI), nuevo récord de la pandemia. La ocupación de camas UTI, más allá de la dolencia que explique la internación del paciente, a nivel nacional promedia el 78,1%, mientras que en el AMBA llega al 77,3%.
# Además, se informó que ayer fueron procesados 107.697 testeos y desde el inicio del brote se realizaron 14.067.367 pruebas diagnósticas para esta enfermedad.
# En el “Monitor Público de Vacunación”, que comenzó a difundir el Gobierno en febrero, se indica que, con datos hasta el mediodía, se distribuyeron 15.373.890 dosis. De ese total, 12.497.078 ya se aplicaron: 9.667.003 personas recibieron una sola dosis y 2.830.075 completaron el proceso de vacunación.
# Por otra parte, el Ministerio de Salud de la Nación informó que comenzará mañana la distribución en todo el país de una partida de 2.119.000 vacunas Astrazeneca que llegarán a todas las jurisdicciones.
# De acuerdo al criterio dispuesto en base a la cantidad de población de cada distrito, las dosis para cada provincia serán:
# Las dosis que se repartirán son las que llegaron ayer al Aeropuerto de Ezeiza con las vacunas cuyo principio activo se produjo en la Argentina y que se suman a las 2.785.200 dosis que arribaron la semana pasada, entre las Sputnik V y las desarrolladas en conjunto por la Universidad de Oxford y AstraZeneca que fueron adquiridas tanto por el mecanismo Covax de la OMS como en un acuerdo con la empresa farmacéutica británica.
# La Argentina ya recibió 17.631.945 vacunas: 8.115.745 corresponden a Sputnik V (6.975.585 del componente 1 y 1.140.160 del componente 2), 4.000.000 a Sinopharm, 580.000 a Astrazeneca - Covishield, 1.944.000 a Astrazeneca por el mecanismo Covax y 2.992.200 a las de Astrazeneca y Oxford cuyo principio activo se produjo en la Argentina.

# %% [markdown]
# ### Iteración sobre varios urls
#
# Una de las cosas interesantes del scrappeo es poder iterar sobre varias página y extraer información en forma sistemática. Extraigamos el título y la descripción para un conjunto de urls. Básicamente es hacer lo que hicimos para una nota varias veces:

# %%
urls
# Out:
# ['https://www.lanacion.com.ar/sociedad/coronavirus-en-la-argentina-reportan-641-muertos-y-35355-nuevos-casos-nid01062021/',
#  'https://www.lanacion.com.ar/el-mundo/la-trama-mafiosa-detras-de-la-venta-de-terrenos-en-un-exclusivo-barrio-de-jose-ignacio-nid01062021/',
#  'https://www.lanacion.com.ar/politica/murio-el-consultor-y-analista-politico-jorge-giacobbe-nid01062021/',
#  'https://www.lanacion.com.ar/seguridad/dumbo-el-capo-narco-que-se-mudo-a-martinez-y-dejo-el-mate-tibio-para-poder-escapar-de-la-policia-nid01062021/',
#  'https://www.lanacion.com.ar/sociedad/covid-19-avanza-en-el-instituto-leloir-otra-vacuna-argentina-nid01062021/',
#  'https://www.lanacion.com.ar/deportes/futbol/la-generosa-despedida-de-sergio-aguero-con-los-empleados-del-manchester-city-mas-de-60-relojes-nid01062021/']

# %%
# Barremos en el listado de urls 
# Le ponemos un try-except para ignorar errores
for url in urls: 
  
  try:
  
    # Hacemos request al url actual
    response = requests.get(url)

    # Creamos la sopa
    soup = BS(response.content)

    # Identificamos el título
    title = soup.find(attrs = {"class": "com-title --threexl"}).text

    # Identificamos la descripción
    description = soup.find(attrs = {"class": "com-subhead --bajada --m-xs"}).text

    # Printeamos ambas y dejamos un espacio entre nota y nota
    print(title)
    print(description)
    print('\n\n')
  
  except:
    pass
# Out:
# Coronavirus en la Argentina: reportan 641 muertos y 35.355 nuevos casos
# Los fallecidos en el país se acercan a los 79.000, mientras los internados en Unidades de Terapia Intensiva continúan en alza
#
#
#
# La trama mafiosa detrás de la venta de terrenos de argentinos en un exclusivo barrio de José Ignacio
# Un escribano y un operador inmobiliario, junto con varios cómplices, se hacían de valiosas propiedades que pertenecían a personas fallecidas, entre ellas argentinas, y las vendía a un tercio de su valor
#
#
#
# Murió el consultor y analista político Jorge Giacobbe
# Era el presidente de Giacobbe & Asociados Opinión Pública S.A. desde el año 2000; había estudiado Economía en la Universidad de Morón y Derecho en la Universidad de Buenos Aires
#
#
#
# Dumbo: el capo narco que se mudó a Martínez y dejó el mate tibio para poder escapar de la policía
# Raúl Martín Maylli Rivera, acusado de liderar una organización criminal en el barrio Padre Mugica, de Villa Lugano, volvió a fugarse cuando fueron a buscarlo a la casa de dos plantas en la que se había instalado con su familia
#
#
#
# Covid-19. Avanza en el Instituto Leloir otra vacuna argentina
# Sería de una sola dosis y con menos sustancia activa; arrojó resultados muy promisorios en animales;  el proyecto se suma al de la Universidad Nacional de San Martín, que ya está en etapa preclínica
#
#
#
# La generosa despedida de Sergio Agüero con los empleados del Manchester City: más de 60 relojes, dinero y una lujosa camioneta
# El jugador argentino cerró una década gloriosa en la Premier con regalos personalizados para las personas del club con las que compartió grandes momentos

# %% [markdown]
# ### Algunas conclusiones que sacamos de aquí
#
# Vimos un ejemplo concreto de cómo extraer contenido de ciertas páginas. Algunas aclaraciones:
#
# - No suele ser lo mejor hacer esto desde un colab. Lo ideal es tener algún bot creado localmente.
# - Si vamos a iterar sobre varias páginas tener presente recomendaciones tales como no hacer demasiadas requests en un período de tiempo, que podrían resultar en prohibirnos el acceso a diferentes páginas.
# - Lo que vimos acá no maneja contenido dinámico: en particular, en el ejemplo que vimos la información va emergiendo a medida que scrolleamos.
#
# El manejo de contenido dinámico es con el lenguaje javascript y podemos manejarlo con la librería *selenium*. Esto lo vamos a hacer corriendo el siguiente script por fuera del  (en spyder por ejemplo o desde la terminal *python script.py*). Con este podemos obtener muchos más enlaces y luego scrappear cada uno de ellos:
#
# ~~~
# # -*- coding: utf-8 -*-
# """
# El siguiente código es complemento de la notebook sobre el manejo
# de contenido estático de una paǵina de la clase de web scrapping.
# La idea aquí es que en muchas páginas la información se muestra en forma dinámica,
# por lo que vamos a necesitar manejar cosas de javascript.
# Esto lo podemos hacer con selenium,
# que simula un navegador web como si fuera un usuario más.
# """
# # ---------- Importación de librerías ----------- #
#
# # Importamos algunos módulos de selenium que nos van a servir
# from selenium import webdriver
# from selenium.webdriver.chrome.options import Options
#
# # Importamos la libreŕía time para esperar cierto tiempo
# import time
#
# # ---------------------------------------------- #
#
# # ------------ Creación del navegador --------- #
#
# # Para que selenium ande hay que descargar un driver, que depende de cada
# # navegador y sistema operativo, y se descarga en la página de selenium:
# # https://selenium-python.readthedocs.io/installation.html#drivers
#
# # Para especificar donde está se lo pasamos
# # como argumento cuando inicializamos el navegador.
# # Para linux, hay que convertirlo en ejecutable chmod +x driver
# # Para mas detalles:
# # https://stackoverflow.com/questions/42478591/python-selenium-chrome-webdriver
#
# PATH_DRIVER = "..." # Cambiar aquí dónde está
#
# # Creamos un navegador tipo Chrome.
# # Podemos decirle que navegue en forma explícita o ímplícita.
# # La segunda lo logramos descomentando la línea "--headless".
#
# chrome_options = Options()
# chrome_options.add_argument("--headless")
#
# # Creación del navegador
# driver = webdriver.Chrome(executable_path = PATH_DRIVER, options = chrome_options)
#
# # -------------------------------------------- #
#
# # --------- Visitamos la página -------------- #
#
# # Visitamos la página y esperamos 5 segundos a que todo cargue bien
# driver.get("https://www.lanacion.com.ar")
# time.sleep(5)
#
# # Acá manejamos algo dinámico:
# # Dado que en La Nación el contenido aparece scrolleando vamos a hacer eso.
# # Todos las líneas de código en javascript se pueden ejecutar
# # con ".execute_script" e insertando el código correspondiente allí.
# # Lo que vamos a hacer acá es scrollear varias veces
# # hasta el final de la página y esperar un poco a que se cargue bien la página
#
# for iteration in range(6):
# 	driver.execute_script("window.scrollTo(0,document.body.scrollHeight);")
# 	time.sleep(2)
#
# # Una vez que dejamos scrollear identicamos todos los bloques asociados a las notas (ver notebook).
# # Cómo se busca en selenium? https://selenium-python.readthedocs.io/locating-elements.html
#
# elements = driver.find_elements_by_class_name("com-title")
#
# # Ahora guardamos los enlaces de cada elemento
# hrefs = []
# for element in elements:
#     try:
# 	href = element.find_element_by_tag_name("a").get_attribute("href")
# 	hrefs.append(href)
#     except:
#         pass
#
# # Guardamos los enlaces en un archivo
# fp = open('links.txt','w')
# for href in hrefs:
# 	fp.write(href + '\n')
# fp.close()
#
# # Finalmente cerramos todas las sesiones de navegación que abrimos.
# # Son necesarias ambas líneas (una cierra la pestaña, la otra toda el navegador)
#
# driver.close()
# driver.quit()
# ~~~
